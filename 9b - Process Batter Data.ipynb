# %% [markdown]
# Add / Process Batter Data
#
#     - Now, we need to process this data and augment our game-level data frame
#     - For each game, we want the trailing statistics for each player designated in the starting lineup
#     - Need to add the statistics for those 18 players to each game
#     - From that, we may want to derive "team-level" averages to simplify our feature set
#     - NOTE: this will complicate things when we "go into production" and try and use this model for predicting new games

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_columns',5000)
pd.set_option('display.max_rows',5000)

# %%
df = pd.read_csv('df_bp7.csv', low_memory=False)
df.shape
# Out:
# (132128, 611)

# %% [markdown]
#     - When aggregating pitcher's past performance, we use default values to "smooth out" players with little / no history
#     - With batters, this is more complicated, as different positions have different "typical" hitting capabilities
#     - (Separate issue: should we be using training data with pitchers hitting?!?!)

# %%
def roll_column(df, col, winsize):
    # do the standard Pandas rolling calc
    t_col = df[col].rolling(winsize, closed='left').sum().to_numpy()
    
    # for the early columns, just do a rolling sum from the beginning
    t_col[:winsize] = np.concatenate(([0],df[col].iloc[:(winsize)].cumsum().to_numpy()[:-1]))

    return(t_col)

# %%
## Set up position level defaults
dd = {}
dd_p = {'batavg': .100, 'obp': .150, 'slg': .180, 'slgmod': .220, 'obs': .330, 'sobat': .3}
dd_ss_c = {'batavg': .205, 'obp': .260, 'slg': .300, 'slgmod': .320, 'obs': .540, 'sobat': .25}
dd_2b_3b = {'batavg': .240, 'obp': .280, 'slg': .350, 'slgmod': .355, 'obs': .630, 'sobat': .2}
dd_rest = {'batavg': .255, 'obp': .310, 'slg': .380, 'slgmod': .430, 'obs': .690, 'sobat': .2}
dd['p'] = dd_p
dd['ss'] = dd_ss_c
dd['c'] = dd_ss_c
dd['2b'] = dd_2b_3b
dd['3b'] = dd_2b_3b
dd['1b'] = dd_rest
dd['lf'] = dd_rest
dd['rf'] = dd_rest
dd['cf'] = dd_rest
dd['ph'] = dd_rest
dd['pr'] = dd_ss_c
dd['dh'] = dd_rest

# %%
def process_batter_df(p_id, dict_def):
    fname = 'data/batter_data/batting_data_'+p_id+'.csv'
    try:
        batter_df = pd.read_csv(fname)
        pos = batter_df.Pos.mode()[0]
        
        # corner cases where the most common position was a pair
        if ',' in pos:
            pos = pos.split(',')[0]
            
        batter_df['Date'] = (pd.to_datetime(batter_df.Date).astype(str).str.replace('-','')).astype(int)
        t_col = batter_df['dblhead_num'].copy()
        t_col[np.isnan(t_col)] = 0
        batter_df['dblheader_int'] = t_col.astype(int)
        for winsize in [30,75,162,350]:
            suff = str(winsize)
            for raw_col in ['AB','BB','H','2B','3B','HR','HBP','SO','SB','CS']:
                new_col = 'rollsum_'+raw_col+'_'+suff
                batter_df[new_col] = roll_column(batter_df, raw_col, winsize)

            ab_per_game_def = 2
            pa_per_game_def = 2
            batavg_def = dict_def[pos]['batavg']
            obp_def = dict_def[pos]['obp']
            slg_def = dict_def[pos]['slg']
            slgmod_def = dict_def[pos]['slgmod']
            so_bat_perc_def = dict_def[pos]['sobat']

            # Columns created by aggregation above
            ab_col = 'rollsum_AB_'+str(winsize)
            h_col = 'rollsum_H_'+str(winsize)
            bb_col = 'rollsum_BB_'+str(winsize)
            hbp_col = 'rollsum_HBP_'+str(winsize)
            doub_col = 'rollsum_2B_'+str(winsize)
            trip_col = 'rollsum_3B_'+str(winsize)
            hr_col = 'rollsum_HR_'+str(winsize)
            so_col = 'rollsum_SO_'+str(winsize)

            # Columns I will define below
            abmod_col = 'ABmod_'+str(winsize)
            fakeab_col = 'fakeAB_'+str(winsize)
            pa_col = 'PA_'+str(winsize)
            pamod_col = 'PAmod_'+str(winsize)
            fakepa_col = 'fakePA_'+str(winsize)
            xb_col = 'XB_'+str(winsize) # represents extra bases beyond hits
            slg_col = 'SLG_'+str(winsize)
            slgmod_col = 'SLGmod_'+str(winsize)
            batavg_col = 'BATAVG_'+str(winsize)
            so_bat_perc_col = 'SObat_perc_'+str(winsize)
            obp_col = 'OBP_'+str(winsize)
            obs_col = 'OBS_'+str(winsize)

            # calculate BATAVG, with smoothing for low AB numbers
            batter_df[abmod_col] = np.maximum(batter_df[ab_col],winsize*ab_per_game_def)
            batter_df[fakeab_col] = np.minimum(batter_df[abmod_col]-batter_df[ab_col],0)
            batter_df[batavg_col] = (batter_df[h_col] + (batter_df[fakeab_col]*batavg_def))/(batter_df[abmod_col])

            # calculate SLG, with smoothing for low AB numbers
            batter_df[xb_col] = batter_df[doub_col] + 2*batter_df[trip_col] + 3*batter_df[hr_col]
            batter_df[slg_col] = (batter_df[h_col] + batter_df[xb_col] + 
                                     (batter_df[fakeab_col]*slg_def))/(batter_df[abmod_col])

            # calculate OBP, with smoothing for low PA numbers
            batter_df[pa_col] = batter_df[ab_col]+batter_df[bb_col]+batter_df[hbp_col]
            batter_df[pamod_col] = np.maximum(batter_df[pa_col],winsize*pa_per_game_def)
            batter_df[fakepa_col] = np.minimum(batter_df[pamod_col]-batter_df[pa_col],0)
            batter_df[obp_col] = (batter_df[h_col] + batter_df[bb_col] + batter_df[hbp_col]
                                  + (batter_df[fakepa_col]*obp_def))/(
                                    batter_df[pamod_col])

            # calculate SLGmod, with smoothing for low PA numbers
            batter_df[slgmod_col] = (batter_df[so_col] + batter_df[bb_col] + batter_df[hbp_col] 
                                     +batter_df[xb_col] + (batter_df[fakepa_col]*slgmod_def))/(
                                    batter_df[pamod_col])

            # calculate SObat_perc, with smoothing for low PA numbers
            batter_df[so_bat_perc_col] = (batter_df[so_col] + (batter_df[fakepa_col]*so_bat_perc_def))/(
                                    batter_df[pamod_col])

            # calculate OBS
            batter_df[obs_col] = batter_df[obp_col]+batter_df[slg_col]


            batter_df['date_dblhead'] = (batter_df['Date'].astype(str) + batter_df['dblheader_int'].astype(str)).astype(int)
            batter_df.set_index('date_dblhead', inplace=True)
    except:
        try:
            print(f'issue for {fname} at position {pos}, returning None')
        except:
            print(f'issue for {fname}, returning None')
        batter_df = None
    return(batter_df)

# %%
batter_ids = np.array([])
for num in range(1,10):
    for suffix in ['_h','_v']:
        # Check whether this should be '_id' or '_name'
        colname = 'batter'+str(num)+'_name'+suffix
        batter_ids = np.concatenate((batter_ids, pd.unique(df[colname])))
batter_ids = np.unique(batter_ids)

# %%
## Create a batter data dictionary from the saved batter files
batter_data_dict = {}
for i,b_id in enumerate(batter_ids):
    if i%100==0:
        print(i)
    batter_data_dict[b_id] = process_batter_df(b_id, dd)
# Out:
# 0
# issue for data/batter_data/batting_data_aaroh101.csv, returning None
# issue for data/batter_data/batting_data_aarot101.csv, returning None
# issue for data/batter_data/batting_data_abada001.csv, returning None
# issue for data/batter_data/batting_data_abadf001.csv, returning None
# issue for data/batter_data/batting_data_abboc001.csv, returning None
# issue for data/batter_data/batting_data_abboj001.csv, returning None
# issue for data/batter_data/batting_data_abboj002.csv, returning None
# issue for data/batter_data/batting_data_abbok001.csv, returning None
# issue for data/batter_data/batting_data_abbok002.csv, returning None
# issue for data/batter_data/batting_data_abbop001.csv, returning None
# issue for data/batter_data/batting_data_aberb001.csv, returning None
# issue for data/batter_data/batting_data_aberr001.csv, returning None
# issue for data/batter_data/batting_data_abert101.csv, returning None
# issue for data/batter_data/batting_data_abnes001.csv, returning None
# issue for data/batter_data/batting_data_abrac001.csv, returning None
# issue for data/batter_data/batting_data_abrac101.csv, returning None
# issue for data/batter_data/batting_data_abreb001.csv, returning None
# issue for data/batter_data/batting_data_abrej001.csv, returning None
# issue for data/batter_data/batting_data_abrej003.csv, returning None
# issue for data/batter_data/batting_data_abret001.csv, returning None
# issue for data/batter_data/batting_data_acevj001.csv, returning None
# issue for data/batter_data/batting_data_acevj002.csv, returning None
# issue for data/batter_data/batting_data_ackej001.csv, returning None
# issue for data/batter_data/batting_data_acket101.csv, returning None
# issue for data/batter_data/batting_data_ackld001.csv, returning None
# issue for data/batter_data/batting_data_acklf101.csv, returning None
# issue for data/batter_data/batting_data_acose101.csv, returning None
# issue for data/batter_data/batting_data_acunr001.csv, returning None
# issue for data/batter_data/batting_data_adaij101.csv, returning None
# issue for data/batter_data/batting_data_adamb101.csv, returning None
# issue for data/batter_data/batting_data_adamb103.csv, returning None
# issue for data/batter_data/batting_data_adamb105.csv, returning None
# issue for data/batter_data/batting_data_adamc001.csv, returning None
# issue for data/batter_data/batting_data_adamd001.csv, returning None
# issue for data/batter_data/batting_data_adamd101.csv, returning None
# issue for data/batter_data/batting_data_adamg101.csv, returning None
# issue for data/batter_data/batting_data_adamj001.csv, returning None
# issue for data/batter_data/batting_data_adaml001.csv, returning None
# issue for data/batter_data/batting_data_adamm002.csv, returning None
# issue for data/batter_data/batting_data_adamm101.csv, returning None
# issue for data/batter_data/batting_data_adamm102.csv, returning None
# issue for data/batter_data/batting_data_adamr001.csv, returning None
# issue for data/batter_data/batting_data_adamr002.csv, returning None
# issue for data/batter_data/batting_data_adamr003.csv, returning None
# issue for data/batter_data/batting_data_adamr004.csv, returning None
# issue for data/batter_data/batting_data_adams101.csv, returning None
# issue for data/batter_data/batting_data_adamt001.csv, returning None
# issue for data/batter_data/batting_data_adamw002.csv, returning None
# issue for data/batter_data/batting_data_adcoj101.csv, returning None
# issue for data/batter_data/batting_data_addib101.csv, returning None
# issue for data/batter_data/batting_data_adduj001.csv, returning None
# issue for data/batter_data/batting_data_adduj002.csv, returning None
# issue for data/batter_data/batting_data_adelj001.csv, returning None
# issue for data/batter_data/batting_data_adkig101.csv, returning None
# issue for data/batter_data/batting_data_adled101.csv, returning None
# issue for data/batter_data/batting_data_adlet001.csv, returning None
# issue for data/batter_data/batting_data_adonj001.csv, returning None
# issue for data/batter_data/batting_data_adrie001.csv, returning None
# issue for data/batter_data/batting_data_afent001.csv, returning None
# issue for data/batter_data/batting_data_affej001.csv, returning None
# issue for data/batter_data/batting_data_agbab001.csv, returning None
# issue for data/batter_data/batting_data_ageet101.csv, returning None
# issue for data/batter_data/batting_data_aggah101.csv, returning None
# issue for data/batter_data/batting_data_agrad001.csv, returning None
# issue for data/batter_data/batting_data_agual001.csv, returning None
# issue for data/batter_data/batting_data_aguic001.csv, returning None
# issue for data/batter_data/batting_data_aguih101.csv, returning None
# issue for data/batter_data/batting_data_aguij001.csv, returning None
# issue for data/batter_data/batting_data_aguir001.csv, returning None
# issue for data/batter_data/batting_data_aguir002.csv, returning None
# issue for data/batter_data/batting_data_ahmen001.csv, returning None
# issue for data/batter_data/batting_data_aikew001.csv, returning None
# issue for data/batter_data/batting_data_aingd101.csv, returning None
# issue for data/batter_data/batting_data_ainsk001.csv, returning None
# issue for data/batter_data/batting_data_akerb101.csv, returning None
# issue for data/batter_data/batting_data_akink001.csv, returning None
# issue for data/batter_data/batting_data_akiys001.csv, returning None
# issue for data/batter_data/batting_data_albea001.csv, returning None
# issue for data/batter_data/batting_data_albeb101.csv, returning None
# issue for data/batter_data/batting_data_albeh001.csv, returning None
# issue for data/batter_data/batting_data_albem001.csv, returning None
# issue for data/batter_data/batting_data_albio001.csv, returning None
# issue for data/batter_data/batting_data_alcaa001.csv, returning None
# issue for data/batter_data/batting_data_alcai001.csv, returning None
# issue for data/batter_data/batting_data_alcal101.csv, returning None
# issue for data/batter_data/batting_data_alcas001.csv, returning None
# issue for data/batter_data/batting_data_alcas002.csv, returning None
# issue for data/batter_data/batting_data_alcas101.csv, returning None
# issue for data/batter_data/batting_data_aldrc001.csv, returning None
# issue for data/batter_data/batting_data_aldrm001.csv, returning None
# issue for data/batter_data/batting_data_alexd001.csv, returning None
# issue for data/batter_data/batting_data_alexd101.csv, returning None
# issue for data/batter_data/batting_data_alexg101.csv, returning None
# issue for data/batter_data/batting_data_alexm001.csv, returning None
# issue for data/batter_data/batting_data_alexm101.csv, returning None
# issue for data/batter_data/batting_data_alexs001.csv, returning None
# issue for data/batter_data/batting_data_alext001.csv, returning None
# issue for data/batter_data/batting_data_alfaj001.csv, returning None
# issue for data/batter_data/batting_data_alfaj002.csv, returning None
# issue for data/batter_data/batting_data_alfoa002.csv, returning None
# 100
# issue for data/batter_data/batting_data_alfoe001.csv, returning None
# issue for data/batter_data/batting_data_alfoe002.csv, returning None
# issue for data/batter_data/batting_data_alicl001.csv, returning None
# issue for data/batter_data/batting_data_allaa001.csv, returning None
# issue for data/batter_data/batting_data_allak001.csv, returning None
# issue for data/batter_data/batting_data_allea001.csv, returning None
# issue for data/batter_data/batting_data_alleb001.csv, returning None
# issue for data/batter_data/batting_data_alleb105.csv, returning None
# issue for data/batter_data/batting_data_allec001.csv, returning None
# issue for data/batter_data/batting_data_alled001.csv, returning None
# issue for data/batter_data/batting_data_alled101.csv, returning None
# issue for data/batter_data/batting_data_allee101.csv, returning None
# issue for data/batter_data/batting_data_alleg001.csv, returning None
# issue for data/batter_data/batting_data_alleg002.csv, returning None
# issue for data/batter_data/batting_data_alleg101.csv, returning None
# issue for data/batter_data/batting_data_alleh104.csv, returning None
# issue for data/batter_data/batting_data_allej001.csv, returning None
# issue for data/batter_data/batting_data_allej101.csv, returning None
# issue for data/batter_data/batting_data_allek101.csv, returning None
# issue for data/batter_data/batting_data_allel001.csv, returning None
# issue for data/batter_data/batting_data_allel002.csv, returning None
# issue for data/batter_data/batting_data_allel101.csv, returning None
# issue for data/batter_data/batting_data_allen001.csv, returning None
# issue for data/batter_data/batting_data_allen002.csv, returning None
# issue for data/batter_data/batting_data_aller001.csv, returning None
# issue for data/batter_data/batting_data_aller101.csv, returning None
# issue for data/batter_data/batting_data_allib101.csv, returning None
# issue for data/batter_data/batting_data_allib103.csv, returning None
# issue for data/batter_data/batting_data_allig101.csv, returning None
# issue for data/batter_data/batting_data_allrb001.csv, returning None
# issue for data/batter_data/batting_data_almam101.csv, returning None
# issue for data/batter_data/batting_data_almoa001.csv, returning None
# issue for data/batter_data/batting_data_almoa002.csv, returning None
# issue for data/batter_data/batting_data_almob001.csv, returning None
# issue for data/batter_data/batting_data_almoe001.csv, returning None
# issue for data/batter_data/batting_data_almoz001.csv, returning None
# issue for data/batter_data/batting_data_alomr001.csv, returning None
# issue for data/batter_data/batting_data_aloms001.csv, returning None
# issue for data/batter_data/batting_data_aloms101.csv, returning None
# issue for data/batter_data/batting_data_alonp001.csv, returning None
# issue for data/batter_data/batting_data_alony001.csv, returning None
# issue for data/batter_data/batting_data_alouf101.csv, returning None
# issue for data/batter_data/batting_data_alouj101.csv, returning None
# issue for data/batter_data/batting_data_aloum001.csv, returning None
# issue for data/batter_data/batting_data_aloum101.csv, returning None
# issue for data/batter_data/batting_data_alstd101.csv, returning None
# issue for data/batter_data/batting_data_alstt101.csv, returning None
# issue for data/batter_data/batting_data_altha001.csv, returning None
# issue for data/batter_data/batting_data_altmg101.csv, returning None
# issue for data/batter_data/batting_data_altoj101.csv, returning None
# issue for data/batter_data/batting_data_altuj001.csv, returning None
# issue for data/batter_data/batting_data_alusg101.csv, returning None
# issue for data/batter_data/batting_data_alvac001.csv, returning None
# issue for data/batter_data/batting_data_alvad002.csv, returning None
# issue for data/batter_data/batting_data_alvae001.csv, returning None
# issue for data/batter_data/batting_data_alvaf001.csv, returning None
# issue for data/batter_data/batting_data_alvag001.csv, returning None
# issue for data/batter_data/batting_data_alvah001.csv, returning None
# issue for data/batter_data/batting_data_alvaj003.csv, returning None
# issue for data/batter_data/batting_data_alval101.csv, returning None
# issue for data/batter_data/batting_data_alvao101.csv, returning None
# issue for data/batter_data/batting_data_alvao102.csv, returning None
# issue for data/batter_data/batting_data_alvap001.csv, returning None
# issue for data/batter_data/batting_data_alvar101.csv, returning None
# issue for data/batter_data/batting_data_alvat001.csv, returning None
# issue for data/batter_data/batting_data_alvat002.csv, returning None
# issue for data/batter_data/batting_data_alvav001.csv, returning None
# issue for data/batter_data/batting_data_alvaw001.csv, returning None
# issue for data/batter_data/batting_data_alvay001.csv, returning None
# issue for data/batter_data/batting_data_alvim101.csv, returning None
# issue for data/batter_data/batting_data_alyeb101.csv, returning None
# issue for data/batter_data/batting_data_alzoa001.csv, returning None
# issue for data/batter_data/batting_data_amalj101.csv, returning None
# issue for data/batter_data/batting_data_amara001.csv, returning None
# issue for data/batter_data/batting_data_amarr001.csv, returning None
# issue for data/batter_data/batting_data_amarr002.csv, returning None
# issue for data/batter_data/batting_data_amarr101.csv, returning None
# issue for data/batter_data/batting_data_ambrc001.csv, returning None
# issue for data/batter_data/batting_data_ambut001.csv, returning None
# issue for data/batter_data/batting_data_amele001.csv, returning None
# issue for data/batter_data/batting_data_ameza001.csv, returning None
# issue for data/batter_data/batting_data_amors101.csv, returning None
# issue for data/batter_data/batting_data_amorv101.csv, returning None
# issue for data/batter_data/batting_data_andeb001.csv, returning None
# issue for data/batter_data/batting_data_andeb002.csv, returning None
# issue for data/batter_data/batting_data_andeb003.csv, returning None
# issue for data/batter_data/batting_data_andeb004.csv, returning None
# issue for data/batter_data/batting_data_andeb005.csv, returning None
# issue for data/batter_data/batting_data_andeb006.csv, returning None
# issue for data/batter_data/batting_data_andeb102.csv, returning None
# issue for data/batter_data/batting_data_andec001.csv, returning None
# issue for data/batter_data/batting_data_andec002.csv, returning None
# issue for data/batter_data/batting_data_andec101.csv, returning None
# issue for data/batter_data/batting_data_anded001.csv, returning None
# issue for data/batter_data/batting_data_anded002.csv, returning None
# issue for data/batter_data/batting_data_anded003.csv, returning None
# issue for data/batter_data/batting_data_anded101.csv, returning None
# issue for data/batter_data/batting_data_andef102.csv, returning None
# issue for data/batter_data/batting_data_andeg001.csv, returning None
# issue for data/batter_data/batting_data_andeh101.csv, returning None
# 200
# issue for data/batter_data/batting_data_andei001.csv, returning None
# issue for data/batter_data/batting_data_andej001.csv, returning None
# issue for data/batter_data/batting_data_andej002.csv, returning None
# issue for data/batter_data/batting_data_andej004.csv, returning None
# issue for data/batter_data/batting_data_andej101.csv, returning None
# issue for data/batter_data/batting_data_andej102.csv, returning None
# issue for data/batter_data/batting_data_andek001.csv, returning None
# issue for data/batter_data/batting_data_andel002.csv, returning None
# issue for data/batter_data/batting_data_andem003.csv, returning None
# issue for data/batter_data/batting_data_andem101.csv, returning None
# issue for data/batter_data/batting_data_ander001.csv, returning None
# issue for data/batter_data/batting_data_andes001.csv, returning None
# issue for data/batter_data/batting_data_andes002.csv, returning None
# issue for data/batter_data/batting_data_andes101.csv, returning None
# issue for data/batter_data/batting_data_andet001.csv, returning None
# issue for data/batter_data/batting_data_andet002.csv, returning None
# issue for data/batter_data/batting_data_andir001.csv, returning None
# issue for data/batter_data/batting_data_andrc001.csv, returning None
# issue for data/batter_data/batting_data_andre001.csv, returning None
# issue for data/batter_data/batting_data_andrf101.csv, returning None
# issue for data/batter_data/batting_data_andrj001.csv, returning None
# issue for data/batter_data/batting_data_andrj102.csv, returning None
# issue for data/batter_data/batting_data_andrm001.csv, returning None
# issue for data/batter_data/batting_data_andrm101.csv, returning None
# issue for data/batter_data/batting_data_andrr101.csv, returning None
# issue for data/batter_data/batting_data_andrs001.csv, returning None
# issue for data/batter_data/batting_data_anduj001.csv, returning None
# issue for data/batter_data/batting_data_andum001.csv, returning None
# issue for data/batter_data/batting_data_anglm001.csv, returning None
# issue for data/batter_data/batting_data_ankir001.csv, returning None
# issue for data/batter_data/batting_data_annad001.csv, returning None
# issue for data/batter_data/batting_data_anthe001.csv, returning None
# issue for data/batter_data/batting_data_antom001.csv, returning None
# issue for data/batter_data/batting_data_aokin001.csv, returning None
# issue for data/batter_data/batting_data_aparl101.csv, returning None
# issue for data/batter_data/batting_data_apodb101.csv, returning None
# issue for data/batter_data/batting_data_aposs001.csv, returning None
# issue for data/batter_data/batting_data_appik001.csv, returning None
# issue for data/batter_data/batting_data_appll101.csv, returning None
# issue for data/batter_data/batting_data_aquia001.csv, returning None
# issue for data/batter_data/batting_data_aquij001.csv, returning None
# issue for data/batter_data/batting_data_aquil001.csv, returning None
# issue for data/batter_data/batting_data_aranj001.csv, returning None
# issue for data/batter_data/batting_data_arauj001.csv, returning None
# issue for data/batter_data/batting_data_archc001.csv, returning None
# issue for data/batter_data/batting_data_archj101.csv, returning None
# issue for data/batter_data/batting_data_arcif001.csv, returning None
# issue for data/batter_data/batting_data_arcij101.csv, returning None
# issue for data/batter_data/batting_data_arcio001.csv, returning None
# issue for data/batter_data/batting_data_arcio002.csv, returning None
# issue for data/batter_data/batting_data_arded101.csv, returning None
# issue for data/batter_data/batting_data_ardod001.csv, returning None
# issue for data/batter_data/batting_data_arenj001.csv, returning None
# issue for data/batter_data/batting_data_arenn001.csv, returning None
# issue for data/batter_data/batting_data_arfth101.csv, returning None
# issue for data/batter_data/batting_data_ariaa001.csv, returning None
# issue for data/batter_data/batting_data_ariaa002.csv, returning None
# issue for data/batter_data/batting_data_ariag001.csv, returning None
# issue for data/batter_data/batting_data_ariag002.csv, returning None
# issue for data/batter_data/batting_data_ariaj001.csv, returning None
# issue for data/batter_data/batting_data_arihk001.csv, returning None
# issue for data/batter_data/batting_data_arleb101.csv, returning None
# issue for data/batter_data/batting_data_arlid101.csv, returning None
# issue for data/batter_data/batting_data_arlis101.csv, returning None
# issue for data/batter_data/batting_data_armam001.csv, returning None
# issue for data/batter_data/batting_data_armat001.csv, returning None
# issue for data/batter_data/batting_data_armat002.csv, returning None
# issue for data/batter_data/batting_data_armbe101.csv, returning None
# issue for data/batter_data/batting_data_armsj001.csv, returning None
# issue for data/batter_data/batting_data_arndl001.csv, returning None
# issue for data/batter_data/batting_data_arnoc101.csv, returning None
# issue for data/batter_data/batting_data_arnoj001.csv, returning None
# issue for data/batter_data/batting_data_arocr001.csv, returning None
# issue for data/batter_data/batting_data_arozr001.csv, returning None
# issue for data/batter_data/batting_data_arral001.csv, returning None
# issue for data/batter_data/batting_data_arrig101.csv, returning None
# issue for data/batter_data/batting_data_arrij001.csv, returning None
# issue for data/batter_data/batting_data_arrob001.csv, returning None
# issue for data/batter_data/batting_data_arroc001.csv, returning None
# issue for data/batter_data/batting_data_arrol101.csv, returning None
# issue for data/batter_data/batting_data_arror001.csv, returning None
# issue for data/batter_data/batting_data_arrue001.csv, returning None
# issue for data/batter_data/batting_data_arteh001.csv, returning None
# issue for data/batter_data/batting_data_asadr001.csv, returning None
# issue for data/batter_data/batting_data_aschc001.csv, returning None
# issue for data/batter_data/batting_data_asenm001.csv, returning None
# issue for data/batter_data/batting_data_ashba001.csv, returning None
# issue for data/batter_data/batting_data_ashba002.csv, returning None
# issue for data/batter_data/batting_data_ashba003.csv, returning None
# issue for data/batter_data/batting_data_ashbr101.csv, returning None
# issue for data/batter_data/batting_data_ashea001.csv, returning None
# issue for data/batter_data/batting_data_ashft001.csv, returning None
# issue for data/batter_data/batting_data_ashlb001.csv, returning None
# issue for data/batter_data/batting_data_ashln001.csv, returning None
# issue for data/batter_data/batting_data_asprb101.csv, returning None
# issue for data/batter_data/batting_data_asprk101.csv, returning None
# issue for data/batter_data/batting_data_asseb101.csv, returning None
# issue for data/batter_data/batting_data_assep001.csv, returning None
# issue for data/batter_data/batting_data_astae001.csv, returning None
# issue for data/batter_data/batting_data_astap001.csv, returning None
# 300
# issue for data/batter_data/batting_data_astrj101.csv, returning None
# issue for data/batter_data/batting_data_astuw001.csv, returning None
# issue for data/batter_data/batting_data_asuac001.csv, returning None
# issue for data/batter_data/batting_data_atill001.csv, returning None
# issue for data/batter_data/batting_data_atkig001.csv, returning None
# issue for data/batter_data/batting_data_atwet101.csv, returning None
# issue for data/batter_data/batting_data_atwob101.csv, returning None
# issue for data/batter_data/batting_data_aubrm001.csv, returning None
# issue for data/batter_data/batting_data_auder001.csv, returning None
# issue for data/batter_data/batting_data_auerr101.csv, returning None
# issue for data/batter_data/batting_data_augeb001.csv, returning None
# issue for data/batter_data/batting_data_augud101.csv, returning None
# issue for data/batter_data/batting_data_aultd101.csv, returning None
# issue for data/batter_data/batting_data_aumop001.csv, returning None
# issue for data/batter_data/batting_data_aurir001.csv, returning None
# issue for data/batter_data/batting_data_ausmb001.csv, returning None
# issue for data/batter_data/batting_data_austj002.csv, returning None
# issue for data/batter_data/batting_data_austr101.csv, returning None
# issue for data/batter_data/batting_data_austt001.csv, returning None
# issue for data/batter_data/batting_data_autra101.csv, returning None
# issue for data/batter_data/batting_data_avela001.csv, returning None
# issue for data/batter_data/batting_data_avenb001.csv, returning None
# issue for data/batter_data/batting_data_avere102.csv, returning None
# issue for data/batter_data/batting_data_avers001.csv, returning None
# issue for data/batter_data/batting_data_averx001.csv, returning None
# issue for data/batter_data/batting_data_avila001.csv, returning None
# issue for data/batter_data/batting_data_avilb101.csv, returning None
# issue for data/batter_data/batting_data_avilm001.csv, returning None
# issue for data/batter_data/batting_data_avilp001.csv, returning None
# issue for data/batter_data/batting_data_avilr101.csv, returning None
# issue for data/batter_data/batting_data_axeld001.csv, returning None
# issue for data/batter_data/batting_data_ayalb001.csv, returning None
# issue for data/batter_data/batting_data_ayalb002.csv, returning None
# issue for data/batter_data/batting_data_aybae001.csv, returning None
# issue for data/batter_data/batting_data_aybam001.csv, returning None
# issue for data/batter_data/batting_data_aybaw001.csv, returning None
# issue for data/batter_data/batting_data_azcuj101.csv, returning None
# issue for data/batter_data/batting_data_azocj001.csv, returning None
# issue for data/batter_data/batting_data_azoco001.csv, returning None
# issue for data/batter_data/batting_data_babis101.csv, returning None
# issue for data/batter_data/batting_data_backb001.csv, returning None
# issue for data/batter_data/batting_data_backw001.csv, returning None
# issue for data/batter_data/batting_data_bacsm001.csv, returning None
# issue for data/batter_data/batting_data_badda001.csv, returning None
# issue for data/batter_data/batting_data_badeb001.csv, returning None
# issue for data/batter_data/batting_data_badeh001.csv, returning None
# issue for data/batter_data/batting_data_badgr101.csv, returning None
# issue for data/batter_data/batting_data_bae-j001.csv, returning None
# issue for data/batter_data/batting_data_baekc001.csv, returning None
# issue for data/batter_data/batting_data_baerc001.csv, returning None
# issue for data/batter_data/batting_data_baezd001.csv, returning None
# issue for data/batter_data/batting_data_baezj001.csv, returning None
# issue for data/batter_data/batting_data_baezj101.csv, returning None
# issue for data/batter_data/batting_data_baezk001.csv, returning None
# issue for data/batter_data/batting_data_baezm001.csv, returning None
# issue for data/batter_data/batting_data_bagwj001.csv, returning None
# issue for data/batter_data/batting_data_bahns101.csv, returning None
# issue for data/batter_data/batting_data_bailb001.csv, returning None
# issue for data/batter_data/batting_data_bailb103.csv, returning None
# issue for data/batter_data/batting_data_baile101.csv, returning None
# issue for data/batter_data/batting_data_bailh001.csv, returning None
# issue for data/batter_data/batting_data_bailj001.csv, returning None
# issue for data/batter_data/batting_data_bailj101.csv, returning None
# issue for data/batter_data/batting_data_bailm001.csv, returning None
# issue for data/batter_data/batting_data_bailr001.csv, returning None
# issue for data/batter_data/batting_data_bails102.csv, returning None
# issue for data/batter_data/batting_data_bainh001.csv, returning None
# issue for data/batter_data/batting_data_bairb101.csv, returning None
# issue for data/batter_data/batting_data_baisj001.csv, returning None
# issue for data/batter_data/batting_data_bakec101.csv, returning None
# issue for data/batter_data/batting_data_baked001.csv, returning None
# issue for data/batter_data/batting_data_baked002.csv, returning None
# issue for data/batter_data/batting_data_baked101.csv, returning None
# issue for data/batter_data/batting_data_bakef101.csv, returning None
# issue for data/batter_data/batting_data_bakef103.csv, returning None
# issue for data/batter_data/batting_data_bakef104.csv, returning None
# issue for data/batter_data/batting_data_bakeg101.csv, returning None
# issue for data/batter_data/batting_data_bakej001.csv, returning None
# issue for data/batter_data/batting_data_bakej002.csv, returning None
# issue for data/batter_data/batting_data_bakej103.csv, returning None
# issue for data/batter_data/batting_data_bakes002.csv, returning None
# issue for data/batter_data/batting_data_baket102.csv, returning None
# issue for data/batter_data/batting_data_bakop001.csv, returning None
# issue for data/batter_data/batting_data_balaj101.csv, returning None
# issue for data/batter_data/batting_data_balbs001.csv, returning None
# issue for data/batter_data/batting_data_baldb101.csv, returning None
# issue for data/batter_data/batting_data_baldj002.csv, returning None
# issue for data/batter_data/batting_data_baldr001.csv, returning None
# issue for data/batter_data/batting_data_baldr102.csv, returning None
# issue for data/batter_data/batting_data_balec001.csv, returning None
# issue for data/batter_data/batting_data_balej001.csv, returning None
# issue for data/batter_data/batting_data_balel101.csv, returning None
# issue for data/batter_data/batting_data_balew001.csv, returning None
# issue for data/batter_data/batting_data_ballj001.csv, returning None
# issue for data/batter_data/batting_data_ballj002.csv, returning None
# issue for data/batter_data/batting_data_ballj003.csv, returning None
# issue for data/batter_data/batting_data_banda001.csv, returning None
# issue for data/batter_data/batting_data_bandc001.csv, returning None
# issue for data/batter_data/batting_data_bandj001.csv, returning None
# issue for data/batter_data/batting_data_bands101.csv, returning None
# 400
# issue for data/batter_data/batting_data_baned101.csv, returning None
# issue for data/batter_data/batting_data_bankb001.csv, returning None
# issue for data/batter_data/batting_data_banke101.csv, returning None
# issue for data/batter_data/batting_data_bankg101.csv, returning None
# issue for data/batter_data/batting_data_bankj001.csv, returning None
# issue for data/batter_data/batting_data_bankw001.csv, returning None
# issue for data/batter_data/batting_data_bankw002.csv, returning None
# issue for data/batter_data/batting_data_banna001.csv, returning None
# issue for data/batter_data/batting_data_bannb001.csv, returning None
# issue for data/batter_data/batting_data_bannf001.csv, returning None
# issue for data/batter_data/batting_data_bannr001.csv, returning None
# issue for data/batter_data/batting_data_bantb001.csv, returning None
# issue for data/batter_data/batting_data_banum001.csv, returning None
# issue for data/batter_data/batting_data_barar001.csv, returning None
# issue for data/batter_data/batting_data_barbb001.csv, returning None
# issue for data/batter_data/batting_data_barbb002.csv, returning None
# issue for data/batter_data/batting_data_barbj102.csv, returning None
# issue for data/batter_data/batting_data_barbs101.csv, returning None
# issue for data/batter_data/batting_data_barbs102.csv, returning None
# issue for data/batter_data/batting_data_barcc101.csv, returning None
# issue for data/batter_data/batting_data_bardb001.csv, returning None
# issue for data/batter_data/batting_data_bardd001.csv, returning None
# issue for data/batter_data/batting_data_bardj001.csv, returning None
# issue for data/batter_data/batting_data_barer101.csv, returning None
# issue for data/batter_data/batting_data_barfj001.csv, returning None
# issue for data/batter_data/batting_data_barfj003.csv, returning None
# issue for data/batter_data/batting_data_bargg001.csv, returning None
# issue for data/batter_data/batting_data_barka001.csv, returning None
# issue for data/batter_data/batting_data_barkg001.csv, returning None
# issue for data/batter_data/batting_data_barkk001.csv, returning None
# issue for data/batter_data/batting_data_barkl001.csv, returning None
# issue for data/batter_data/batting_data_barkr102.csv, returning None
# issue for data/batter_data/batting_data_barmc001.csv, returning None
# issue for data/batter_data/batting_data_barna001.csv, returning None
# issue for data/batter_data/batting_data_barnb001.csv, returning None
# issue for data/batter_data/batting_data_barnb002.csv, returning None
# issue for data/batter_data/batting_data_barnc001.csv, returning None
# issue for data/batter_data/batting_data_barnc002.csv, returning None
# issue for data/batter_data/batting_data_barnd001.csv, returning None
# issue for data/batter_data/batting_data_barnf102.csv, returning None
# issue for data/batter_data/batting_data_barnj001.csv, returning None
# issue for data/batter_data/batting_data_barnj002.csv, returning None
# issue for data/batter_data/batting_data_barnl001.csv, returning None
# issue for data/batter_data/batting_data_barnl102.csv, returning None
# issue for data/batter_data/batting_data_barnr104.csv, returning None
# issue for data/batter_data/batting_data_barns001.csv, returning None
# issue for data/batter_data/batting_data_barnt001.csv, returning None
# issue for data/batter_data/batting_data_barod001.csv, returning None
# issue for data/batter_data/batting_data_barod101.csv, returning None
# issue for data/batter_data/batting_data_baros002.csv, returning None
# issue for data/batter_data/batting_data_barrb105.csv, returning None
# issue for data/batter_data/batting_data_barrc101.csv, returning None
# issue for data/batter_data/batting_data_barrf001.csv, returning None
# issue for data/batter_data/batting_data_barrg101.csv, returning None
# issue for data/batter_data/batting_data_barrj001.csv, returning None
# issue for data/batter_data/batting_data_barrj003.csv, returning None
# issue for data/batter_data/batting_data_barrj101.csv, returning None
# issue for data/batter_data/batting_data_barrj102.csv, returning None
# issue for data/batter_data/batting_data_barrk001.csv, returning None
# issue for data/batter_data/batting_data_barrl001.csv, returning None
# issue for data/batter_data/batting_data_barrm001.csv, returning None
# issue for data/batter_data/batting_data_barrm003.csv, returning None
# issue for data/batter_data/batting_data_barrr102.csv, returning None
# issue for data/batter_data/batting_data_barrt002.csv, returning None
# issue for data/batter_data/batting_data_barrt003.csv, returning None
# issue for data/batter_data/batting_data_barrt004.csv, returning None
# issue for data/batter_data/batting_data_bartb001.csv, returning None
# issue for data/batter_data/batting_data_bartb101.csv, returning None
# issue for data/batter_data/batting_data_bartd001.csv, returning None
# issue for data/batter_data/batting_data_bartd101.csv, returning None
# issue for data/batter_data/batting_data_bartd102.csv, returning None
# issue for data/batter_data/batting_data_bartj001.csv, returning None
# issue for data/batter_data/batting_data_bartj002.csv, returning None
# issue for data/batter_data/batting_data_bartj003.csv, returning None
# issue for data/batter_data/batting_data_bartk001.csv, returning None
# issue for data/batter_data/batting_data_bartt101.csv, returning None
# issue for data/batter_data/batting_data_basal001.csv, returning None
# issue for data/batter_data/batting_data_basgm101.csv, returning None
# issue for data/batter_data/batting_data_basie101.csv, returning None
# issue for data/batter_data/batting_data_bassa001.csv, returning None
# issue for data/batter_data/batting_data_bassc001.csv, returning None
# issue for data/batter_data/batting_data_bassk001.csv, returning None
# issue for data/batter_data/batting_data_bassn101.csv, returning None
# issue for data/batter_data/batting_data_bassr101.csv, returning None
# issue for data/batter_data/batting_data_basta001.csv, returning None
# issue for data/batter_data/batting_data_batea001.csv, returning None
# issue for data/batter_data/batting_data_bateb001.csv, returning None
# issue for data/batter_data/batting_data_bated101.csv, returning None
# issue for data/batter_data/batting_data_batej001.csv, returning None
# issue for data/batter_data/batting_data_batej102.csv, returning None
# issue for data/batter_data/batting_data_bathb001.csv, returning None
# issue for data/batter_data/batting_data_batik001.csv, returning None
# issue for data/batter_data/batting_data_batik002.csv, returning None
# issue for data/batter_data/batting_data_batim001.csv, returning None
# issue for data/batter_data/batting_data_batir101.csv, returning None
# issue for data/batter_data/batting_data_batit001.csv, returning None
# issue for data/batter_data/batting_data_batta001.csv, returning None
# issue for data/batter_data/batting_data_batte101.csv, returning None
# issue for data/batter_data/batting_data_batth001.csv, returning None
# issue for data/batter_data/batting_data_battm001.csv, returning None
# 500
# issue for data/batter_data/batting_data_battm101.csv, returning None
# issue for data/batter_data/batting_data_batyb001.csv, returning None
# issue for data/batter_data/batting_data_baueh101.csv, returning None
# issue for data/batter_data/batting_data_bauej001.csv, returning None
# issue for data/batter_data/batting_data_bauet001.csv, returning None
# issue for data/batter_data/batting_data_baugj001.csv, returning None
# issue for data/batter_data/batting_data_baumf101.csv, returning None
# issue for data/batter_data/batting_data_baumf102.csv, returning None
# issue for data/batter_data/batting_data_baumj101.csv, returning None
# issue for data/batter_data/batting_data_baumj102.csv, returning None
# issue for data/batter_data/batting_data_baumr101.csv, returning None
# issue for data/batter_data/batting_data_bautd001.csv, returning None
# issue for data/batter_data/batting_data_bautd002.csv, returning None
# issue for data/batter_data/batting_data_bautj001.csv, returning None
# issue for data/batter_data/batting_data_bautj002.csv, returning None
# issue for data/batter_data/batting_data_bautr001.csv, returning None
# issue for data/batter_data/batting_data_baxej101.csv, returning None
# issue for data/batter_data/batting_data_baxem101.csv, returning None
# issue for data/batter_data/batting_data_baxtm001.csv, returning None
# issue for data/batter_data/batting_data_bay-j001.csv, returning None
# issue for data/batter_data/batting_data_bayld001.csv, returning None
# issue for data/batter_data/batting_data_bazay001.csv, returning None
# issue for data/batter_data/batting_data_beacb001.csv, returning None
# issue for data/batter_data/batting_data_bealb101.csv, returning None
# issue for data/batter_data/batting_data_beamc101.csv, returning None
# issue for data/batter_data/batting_data_beamc102.csv, returning None
# issue for data/batter_data/batting_data_beamt001.csv, returning None
# issue for data/batter_data/batting_data_beanb001.csv, returning None
# issue for data/batter_data/batting_data_beanb002.csv, returning None
# issue for data/batter_data/batting_data_bearl101.csv, returning None
# issue for data/batter_data/batting_data_bearm101.csv, returning None
# issue for data/batter_data/batting_data_bearr101.csv, returning None
# issue for data/batter_data/batting_data_beart101.csv, returning None
# issue for data/batter_data/batting_data_beasl101.csv, returning None
# issue for data/batter_data/batting_data_beatb001.csv, returning None
# issue for data/batter_data/batting_data_beatm001.csv, returning None
# issue for data/batter_data/batting_data_beauj101.csv, returning None
# issue for data/batter_data/batting_data_beavb001.csv, returning None
# issue for data/batter_data/batting_data_beckc101.csv, returning None
# issue for data/batter_data/batting_data_beckf101.csv, returning None
# issue for data/batter_data/batting_data_beckg001.csv, returning None
# issue for data/batter_data/batting_data_beckg101.csv, returning None
# issue for data/batter_data/batting_data_beckj001.csv, returning None
# issue for data/batter_data/batting_data_beckj002.csv, returning None
# issue for data/batter_data/batting_data_beckr002.csv, returning None
# issue for data/batter_data/batting_data_beckr101.csv, returning None
# issue for data/batter_data/batting_data_beckt001.csv, returning None
# issue for data/batter_data/batting_data_becqj101.csv, returning None
# issue for data/batter_data/batting_data_bedae001.csv, returning None
# issue for data/batter_data/batting_data_bedeh101.csv, returning None
# issue for data/batter_data/batting_data_bedrc001.csv, returning None
# issue for data/batter_data/batting_data_bedrs001.csv, returning None
# issue for data/batter_data/batting_data_beecm001.csv, returning None
# issue for data/batter_data/batting_data_beedt001.csv, returning None
# issue for data/batter_data/batting_data_beekj001.csv, returning None
# issue for data/batter_data/batting_data_beeld001.csv, returning None
# issue for data/batter_data/batting_data_beenf101.csv, returning None
# issue for data/batter_data/batting_data_beers001.csv, returning None
# issue for data/batter_data/batting_data_beher001.csv, returning None
# issue for data/batter_data/batting_data_behnm101.csv, returning None
# issue for data/batter_data/batting_data_beimj001.csv, returning None
# issue for data/batter_data/batting_data_beirk001.csv, returning None
# issue for data/batter_data/batting_data_belam101.csv, returning None
# issue for data/batter_data/batting_data_belaw101.csv, returning None
# issue for data/batter_data/batting_data_belck001.csv, returning None
# issue for data/batter_data/batting_data_belct001.csv, returning None
# issue for data/batter_data/batting_data_belib101.csv, returning None
# issue for data/batter_data/batting_data_belim001.csv, returning None
# issue for data/batter_data/batting_data_belkt001.csv, returning None
# issue for data/batter_data/batting_data_bellb001.csv, returning None
# issue for data/batter_data/batting_data_bellc001.csv, returning None
# issue for data/batter_data/batting_data_bellc002.csv, returning None
# issue for data/batter_data/batting_data_belld001.csv, returning None
# issue for data/batter_data/batting_data_belld002.csv, returning None
# issue for data/batter_data/batting_data_belle002.csv, returning None
# issue for data/batter_data/batting_data_bellf102.csv, returning None
# issue for data/batter_data/batting_data_bellg001.csv, returning None
# issue for data/batter_data/batting_data_bellg102.csv, returning None
# issue for data/batter_data/batting_data_bellg103.csv, returning None
# issue for data/batter_data/batting_data_bellj001.csv, returning None
# issue for data/batter_data/batting_data_bellj002.csv, returning None
# issue for data/batter_data/batting_data_bellj003.csv, returning None
# issue for data/batter_data/batting_data_bellj004.csv, returning None
# issue for data/batter_data/batting_data_bellj005.csv, returning None
# issue for data/batter_data/batting_data_bellj101.csv, returning None
# issue for data/batter_data/batting_data_bellk101.csv, returning None
# issue for data/batter_data/batting_data_belll101.csv, returning None
# issue for data/batter_data/batting_data_bellm001.csv, returning None
# issue for data/batter_data/batting_data_bellm002.csv, returning None
# issue for data/batter_data/batting_data_bellm003.csv, returning None
# issue for data/batter_data/batting_data_bellr001.csv, returning None
# issue for data/batter_data/batting_data_bellr002.csv, returning None
# issue for data/batter_data/batting_data_bellr003.csv, returning None
# issue for data/batter_data/batting_data_bellr102.csv, returning None
# issue for data/batter_data/batting_data_bellz101.csv, returning None
# issue for data/batter_data/batting_data_belnv001.csv, returning None
# issue for data/batter_data/batting_data_belta001.csv, returning None
# issue for data/batter_data/batting_data_beltb001.csv, returning None
# issue for data/batter_data/batting_data_beltc001.csv, returning None
# issue for data/batter_data/batting_data_belte001.csv, returning None
# 600
# issue for data/batter_data/batting_data_belte002.csv, returning None
# issue for data/batter_data/batting_data_beltr001.csv, returning None
# issue for data/batter_data/batting_data_bemba001.csv, returning None
# issue for data/batter_data/batting_data_benaf001.csv, returning None
# issue for data/batter_data/batting_data_benam001.csv, returning None
# issue for data/batter_data/batting_data_bencj101.csv, returning None
# issue for data/batter_data/batting_data_benda001.csv, returning None
# issue for data/batter_data/batting_data_benea001.csv, returning None
# issue for data/batter_data/batting_data_benea002.csv, returning None
# issue for data/batter_data/batting_data_beneb001.csv, returning None
# issue for data/batter_data/batting_data_bengb101.csv, returning None
# issue for data/batter_data/batting_data_benia002.csv, returning None
# issue for data/batter_data/batting_data_benij001.csv, returning None
# issue for data/batter_data/batting_data_beniy001.csv, returning None
# issue for data/batter_data/batting_data_benjm001.csv, returning None
# issue for data/batter_data/batting_data_bennd101.csv, returning None
# issue for data/batter_data/batting_data_benng001.csv, returning None
# issue for data/batter_data/batting_data_bennh102.csv, returning None
# issue for data/batter_data/batting_data_bennj001.csv, returning None
# issue for data/batter_data/batting_data_bennj002.csv, returning None
# issue for data/batter_data/batting_data_benns001.csv, returning None
# issue for data/batter_data/batting_data_benoj001.csv, returning None
# issue for data/batter_data/batting_data_bensj001.csv, returning None
# issue for data/batter_data/batting_data_bensk001.csv, returning None
# issue for data/batter_data/batting_data_bensw001.csv, returning None
# issue for data/batter_data/batting_data_bentb001.csv, returning None
# issue for data/batter_data/batting_data_benzt001.csv, returning None
# issue for data/batter_data/batting_data_beraj101.csv, returning None
# issue for data/batter_data/batting_data_berbj001.csv, returning None
# issue for data/batter_data/batting_data_berbl101.csv, returning None
# issue for data/batter_data/batting_data_bereb001.csv, returning None
# issue for data/batter_data/batting_data_berej001.csv, returning None
# issue for data/batter_data/batting_data_berej002.csv, returning None
# issue for data/batter_data/batting_data_berej003.csv, returning None
# issue for data/batter_data/batting_data_bergb001.csv, returning None
# issue for data/batter_data/batting_data_bergb002.csv, returning None
# issue for data/batter_data/batting_data_bergc001.csv, returning None
# issue for data/batter_data/batting_data_bergd001.csv, returning None
# issue for data/batter_data/batting_data_bergd002.csv, returning None
# issue for data/batter_data/batting_data_bergj001.csv, returning None
# issue for data/batter_data/batting_data_bergm103.csv, returning None
# issue for data/batter_data/batting_data_bergp001.csv, returning None
# issue for data/batter_data/batting_data_bergs001.csv, returning None
# issue for data/batter_data/batting_data_bergw001.csv, returning None
# issue for data/batter_data/batting_data_bergw101.csv, returning None
# issue for data/batter_data/batting_data_berkj001.csv, returning None
# issue for data/batter_data/batting_data_berkl001.csv, returning None
# issue for data/batter_data/batting_data_berna001.csv, returning None
# issue for data/batter_data/batting_data_bernc102.csv, returning None
# issue for data/batter_data/batting_data_bernd001.csv, returning None
# issue for data/batter_data/batting_data_bernd101.csv, returning None
# issue for data/batter_data/batting_data_bernj101.csv, returning None
# issue for data/batter_data/batting_data_bernr001.csv, returning None
# issue for data/batter_data/batting_data_bernt001.csv, returning None
# issue for data/batter_data/batting_data_bernw001.csv, returning None
# issue for data/batter_data/batting_data_berra001.csv, returning None
# issue for data/batter_data/batting_data_berrc103.csv, returning None
# issue for data/batter_data/batting_data_berrd001.csv, returning None
# issue for data/batter_data/batting_data_berrd002.csv, returning None
# issue for data/batter_data/batting_data_berrg001.csv, returning None
# issue for data/batter_data/batting_data_berrj001.csv, returning None
# issue for data/batter_data/batting_data_berrk101.csv, returning None
# issue for data/batter_data/batting_data_berrn101.csv, returning None
# issue for data/batter_data/batting_data_berrq001.csv, returning None
# issue for data/batter_data/batting_data_berrr101.csv, returning None
# issue for data/batter_data/batting_data_berrs001.csv, returning None
# issue for data/batter_data/batting_data_berry101.csv, returning None
# issue for data/batter_data/batting_data_bertd101.csv, returning None
# issue for data/batter_data/batting_data_bertf101.csv, returning None
# issue for data/batter_data/batting_data_bertj001.csv, returning None
# issue for data/batter_data/batting_data_bertr101.csv, returning None
# issue for data/batter_data/batting_data_bessd101.csv, returning None
# issue for data/batter_data/batting_data_beswj101.csv, returning None
# issue for data/batter_data/batting_data_betay001.csv, returning None
# issue for data/batter_data/batting_data_betew001.csv, returning None
# issue for data/batter_data/batting_data_bethb101.csv, returning None
# issue for data/batter_data/batting_data_bethc001.csv, returning None
# issue for data/batter_data/batting_data_betta001.csv, returning None
# issue for data/batter_data/batting_data_bettc001.csv, returning None
# issue for data/batter_data/batting_data_bettl101.csv, returning None
# issue for data/batter_data/batting_data_bettm001.csv, returning None
# issue for data/batter_data/batting_data_bevak001.csv, returning None
# issue for data/batter_data/batting_data_biagj001.csv, returning None
# issue for data/batter_data/batting_data_bianb001.csv, returning None
# issue for data/batter_data/batting_data_bianj001.csv, returning None
# issue for data/batter_data/batting_data_biant101.csv, returning None
# issue for data/batter_data/batting_data_bibbj001.csv, returning None
# issue for data/batter_data/batting_data_bibea001.csv, returning None
# issue for data/batter_data/batting_data_bichb001.csv, returning None
# issue for data/batter_data/batting_data_bichd001.csv, returning None
# issue for data/batter_data/batting_data_biddr001.csv, returning None
# issue for data/batter_data/batting_data_biebs001.csv, returning None
# issue for data/batter_data/batting_data_bielm001.csv, returning None
# issue for data/batter_data/batting_data_biern001.csv, returning None
# issue for data/batter_data/batting_data_biess001.csv, returning None
# ...
# issue for data/batter_data/batting_data_wilsa102.csv, returning None
# issue for data/batter_data/batting_data_wilsb002.csv, returning None
# issue for data/batter_data/batting_data_wilsb003.csv, returning None
# issue for data/batter_data/batting_data_wilsb103.csv, returning None
# issue for data/batter_data/batting_data_wilsc001.csv, returning None
# issue for data/batter_data/batting_data_wilsc002.csv, returning None
# issue for data/batter_data/batting_data_wilsc003.csv, returning None
# issue for data/batter_data/batting_data_wilsc004.csv, returning None
# issue for data/batter_data/batting_data_wilsd001.csv, returning None
# issue for data/batter_data/batting_data_wilsd002.csv, returning None
# issue for data/batter_data/batting_data_wilsd101.csv, returning None
# issue for data/batter_data/batting_data_wilsd102.csv, returning None
# issue for data/batter_data/batting_data_wilse001.csv, returning None
# issue for data/batter_data/batting_data_wilse102.csv, returning None
# issue for data/batter_data/batting_data_wilsg001.csv, returning None
# issue for data/batter_data/batting_data_wilsh102.csv, returning None
# issue for data/batter_data/batting_data_wilsj001.csv, returning None
# issue for data/batter_data/batting_data_wilsj002.csv, returning None
# 9100
# issue for data/batter_data/batting_data_wilsj003.csv, returning None
# issue for data/batter_data/batting_data_wilsj005.csv, returning None
# issue for data/batter_data/batting_data_wilsj105.csv, returning None
# issue for data/batter_data/batting_data_wilsk001.csv, returning None
# issue for data/batter_data/batting_data_wilsm001.csv, returning None
# issue for data/batter_data/batting_data_wilsm002.csv, returning None
# issue for data/batter_data/batting_data_wilsm003.csv, returning None
# issue for data/batter_data/batting_data_wilsn001.csv, returning None
# issue for data/batter_data/batting_data_wilsn101.csv, returning None
# issue for data/batter_data/batting_data_wilsp001.csv, returning None
# issue for data/batter_data/batting_data_wilsp002.csv, returning None
# issue for data/batter_data/batting_data_wilsr102.csv, returning None
# issue for data/batter_data/batting_data_wilss001.csv, returning None
# issue for data/batter_data/batting_data_wilst001.csv, returning None
# issue for data/batter_data/batting_data_wilst002.csv, returning None
# issue for data/batter_data/batting_data_wilst003.csv, returning None
# issue for data/batter_data/batting_data_wilst004.csv, returning None
# issue for data/batter_data/batting_data_wilsv001.csv, returning None
# issue for data/batter_data/batting_data_wilsw001.csv, returning None
# issue for data/batter_data/batting_data_wince101.csv, returning None
# issue for data/batter_data/batting_data_wincs001.csv, returning None
# issue for data/batter_data/batting_data_windg101.csv, returning None
# issue for data/batter_data/batting_data_wineb101.csv, returning None
# issue for data/batter_data/batting_data_winer001.csv, returning None
# issue for data/batter_data/batting_data_winfd001.csv, returning None
# issue for data/batter_data/batting_data_winge102.csv, returning None
# issue for data/batter_data/batting_data_wingt001.csv, returning None
# issue for data/batter_data/batting_data_winkj002.csv, returning None
# issue for data/batter_data/batting_data_winnh001.csv, returning None
# issue for data/batter_data/batting_data_winnj001.csv, returning None
# issue for data/batter_data/batting_data_winnr001.csv, returning None
# issue for data/batter_data/batting_data_winsd001.csv, returning None
# issue for data/batter_data/batting_data_wintm001.csv, returning None
# issue for data/batter_data/batting_data_wisdp001.csv, returning None
# issue for data/batter_data/batting_data_wisec101.csv, returning None
# issue for data/batter_data/batting_data_wised001.csv, returning None
# issue for data/batter_data/batting_data_wisem001.csv, returning None
# issue for data/batter_data/batting_data_wiser101.csv, returning None
# issue for data/batter_data/batting_data_wislm001.csv, returning None
# issue for data/batter_data/batting_data_wissd101.csv, returning None
# issue for data/batter_data/batting_data_witaj001.csv, returning None
# issue for data/batter_data/batting_data_withc101.csv, returning None
# issue for data/batter_data/batting_data_witmr001.csv, returning None
# issue for data/batter_data/batting_data_wittb001.csv, returning None
# issue for data/batter_data/batting_data_wittb002.csv, returning None
# issue for data/batter_data/batting_data_wittk001.csv, returning None
# issue for data/batter_data/batting_data_wittr101.csv, returning None
# issue for data/batter_data/batting_data_wockj001.csv, returning None
# issue for data/batter_data/batting_data_wohlj001.csv, returning None
# issue for data/batter_data/batting_data_wojca001.csv, returning None
# issue for data/batter_data/batting_data_wojcj101.csv, returning None
# issue for data/batter_data/batting_data_wojne001.csv, returning None
# issue for data/batter_data/batting_data_wolcb001.csv, returning None
# issue for data/batter_data/batting_data_wolfl101.csv, returning None
# issue for data/batter_data/batting_data_wolfr001.csv, returning None
# issue for data/batter_data/batting_data_woltt001.csv, returning None
# issue for data/batter_data/batting_data_womad101.csv, returning None
# issue for data/batter_data/batting_data_womat001.csv, returning None
# issue for data/batter_data/batting_data_wongc001.csv, returning None
# issue for data/batter_data/batting_data_wongk001.csv, returning None
# issue for data/batter_data/batting_data_wongk002.csv, returning None
# issue for data/batter_data/batting_data_wooda001.csv, returning None
# issue for data/batter_data/batting_data_wooda002.csv, returning None
# issue for data/batter_data/batting_data_woodb002.csv, returning None
# issue for data/batter_data/batting_data_woodb003.csv, returning None
# issue for data/batter_data/batting_data_woodb005.csv, returning None
# issue for data/batter_data/batting_data_woodc001.csv, returning None
# issue for data/batter_data/batting_data_woodd102.csv, returning None
# issue for data/batter_data/batting_data_woodd103.csv, returning None
# issue for data/batter_data/batting_data_woodg001.csv, returning None
# issue for data/batter_data/batting_data_woodg101.csv, returning None
# issue for data/batter_data/batting_data_woodh101.csv, returning None
# issue for data/batter_data/batting_data_woodj001.csv, returning None
# issue for data/batter_data/batting_data_woodj003.csv, returning None
# issue for data/batter_data/batting_data_woodj103.csv, returning None
# issue for data/batter_data/batting_data_woodj107.csv, returning None
# issue for data/batter_data/batting_data_woodk002.csv, returning None
# issue for data/batter_data/batting_data_woodm001.csv, returning None
# issue for data/batter_data/batting_data_woodm002.csv, returning None
# issue for data/batter_data/batting_data_woodp102.csv, returning None
# issue for data/batter_data/batting_data_woodr102.csv, returning None
# issue for data/batter_data/batting_data_woods001.csv, returning None
# issue for data/batter_data/batting_data_woodt001.csv, returning None
# issue for data/batter_data/batting_data_woodt002.csv, returning None
# issue for data/batter_data/batting_data_woodt004.csv, returning None
# issue for data/batter_data/batting_data_woodw101.csv, returning None
# issue for data/batter_data/batting_data_woodw103.csv, returning None
# issue for data/batter_data/batting_data_woolf101.csv, returning None
# issue for data/batter_data/batting_data_woots001.csv, returning None
# issue for data/batter_data/batting_data_workb001.csv, returning None
# issue for data/batter_data/batting_data_worlv001.csv, returning None
# issue for data/batter_data/batting_data_worrt002.csv, returning None
# issue for data/batter_data/batting_data_wortc001.csv, returning None
# issue for data/batter_data/batting_data_wortd001.csv, returning None
# issue for data/batter_data/batting_data_wortr102.csv, returning None
# issue for data/batter_data/batting_data_wotur001.csv, returning None
# issue for data/batter_data/batting_data_wrigc102.csv, returning None
# issue for data/batter_data/batting_data_wrigd001.csv, returning None
# issue for data/batter_data/batting_data_wrigd002.csv, returning None
# issue for data/batter_data/batting_data_wrigd003.csv, returning None
# 9200
# issue for data/batter_data/batting_data_wrigg001.csv, returning None
# issue for data/batter_data/batting_data_wrigj001.csv, returning None
# issue for data/batter_data/batting_data_wrigj002.csv, returning None
# issue for data/batter_data/batting_data_wrigk001.csv, returning None
# issue for data/batter_data/batting_data_wrigk101.csv, returning None
# issue for data/batter_data/batting_data_wrigm001.csv, returning None
# issue for data/batter_data/batting_data_wrigr001.csv, returning None
# issue for data/batter_data/batting_data_wrigr002.csv, returning None
# issue for data/batter_data/batting_data_wrigs001.csv, returning None
# issue for data/batter_data/batting_data_wrigt101.csv, returning None
# issue for data/batter_data/batting_data_wrigt102.csv, returning None
# issue for data/batter_data/batting_data_wrigw001.csv, returning None
# issue for data/batter_data/batting_data_wronr001.csv, returning None
# issue for data/batter_data/batting_data_wyatj102.csv, returning None
# issue for data/batter_data/batting_data_wyneb001.csv, returning None
# issue for data/batter_data/batting_data_wynna001.csv, returning None
# issue for data/batter_data/batting_data_wynnb102.csv, returning None
# issue for data/batter_data/batting_data_wynnj101.csv, returning None
# issue for data/batter_data/batting_data_wynnm001.csv, returning None
# issue for data/batter_data/batting_data_wyroj101.csv, returning None
# issue for data/batter_data/batting_data_yajum001.csv, returning None
# issue for data/batter_data/batting_data_yamaj001.csv, returning None
# issue for data/batter_data/batting_data_yan-e001.csv, returning None
# issue for data/batter_data/batting_data_yanch101.csv, returning None
# issue for data/batter_data/batting_data_yarbr001.csv, returning None
# issue for data/batter_data/batting_data_yastc101.csv, returning None
# issue for data/batter_data/batting_data_yastm001.csv, returning None
# issue for data/batter_data/batting_data_yatea101.csv, returning None
# issue for data/batter_data/batting_data_yatet001.csv, returning None
# issue for data/batter_data/batting_data_yeags001.csv, returning None
# issue for data/batter_data/batting_data_yelde001.csv, returning None
# issue for data/batter_data/batting_data_yelic001.csv, returning None
# issue for data/batter_data/batting_data_yelll101.csv, returning None
# issue for data/batter_data/batting_data_yepej001.csv, returning None
# issue for data/batter_data/batting_data_ynoag001.csv, returning None
# issue for data/batter_data/batting_data_ynoah001.csv, returning None
# issue for data/batter_data/batting_data_ynoar001.csv, returning None
# issue for data/batter_data/batting_data_yorkj101.csv, returning None
# issue for data/batter_data/batting_data_yorkm001.csv, returning None
# issue for data/batter_data/batting_data_yorkr101.csv, returning None
# issue for data/batter_data/batting_data_yoshm001.csv, returning None
# issue for data/batter_data/batting_data_yoste001.csv, returning None
# issue for data/batter_data/batting_data_yoste101.csv, returning None
# issue for data/batter_data/batting_data_youkk001.csv, returning None
# issue for data/batter_data/batting_data_youmf001.csv, returning None
# issue for data/batter_data/batting_data_youms001.csv, returning None
# issue for data/batter_data/batting_data_youna001.csv, returning None
# issue for data/batter_data/batting_data_youna002.csv, returning None
# issue for data/batter_data/batting_data_youna003.csv, returning None
# issue for data/batter_data/batting_data_younb101.csv, returning None
# issue for data/batter_data/batting_data_younc003.csv, returning None
# issue for data/batter_data/batting_data_younc004.csv, returning None
# issue for data/batter_data/batting_data_yound001.csv, returning None
# issue for data/batter_data/batting_data_yound003.csv, returning None
# issue for data/batter_data/batting_data_yound004.csv, returning None
# issue for data/batter_data/batting_data_yound103.csv, returning None
# issue for data/batter_data/batting_data_youne001.csv, returning None
# issue for data/batter_data/batting_data_youne002.csv, returning None
# issue for data/batter_data/batting_data_youne003.csv, returning None
# issue for data/batter_data/batting_data_young001.csv, returning None
# issue for data/batter_data/batting_data_younj001.csv, returning None
# issue for data/batter_data/batting_data_younj002.csv, returning None
# issue for data/batter_data/batting_data_younj003.csv, returning None
# issue for data/batter_data/batting_data_younk001.csv, returning None
# issue for data/batter_data/batting_data_younm002.csv, returning None
# issue for data/batter_data/batting_data_younm003.csv, returning None
# issue for data/batter_data/batting_data_younm004.csv, returning None
# issue for data/batter_data/batting_data_younp101.csv, returning None
# issue for data/batter_data/batting_data_younr001.csv, returning None
# issue for data/batter_data/batting_data_younw001.csv, returning None
# issue for data/batter_data/batting_data_yvars101.csv, returning None
# issue for data/batter_data/batting_data_zachc101.csv, returning None
# issue for data/batter_data/batting_data_zachp001.csv, returning None
# issue for data/batter_data/batting_data_zagum002.csv, returning None
# issue for data/batter_data/batting_data_zahng001.csv, returning None
# issue for data/batter_data/batting_data_zambc001.csv, returning None
# issue for data/batter_data/batting_data_zambe001.csv, returning None
# issue for data/batter_data/batting_data_zambv001.csv, returning None
# issue for data/batter_data/batting_data_zamoo101.csv, returning None
# issue for data/batter_data/batting_data_zannd101.csv, returning None
# issue for data/batter_data/batting_data_zaria101.csv, returning None
# issue for data/batter_data/batting_data_zastr001.csv, returning None
# issue for data/batter_data/batting_data_zaucn101.csv, returning None
# issue for data/batter_data/batting_data_zaung001.csv, returning None
# issue for data/batter_data/batting_data_zavas001.csv, returning None
# issue for data/batter_data/batting_data_zawal001.csv, returning None
# issue for data/batter_data/batting_data_zdebj101.csv, returning None
# issue for data/batter_data/batting_data_zebeg101.csv, returning None
# issue for data/batter_data/batting_data_zeidr101.csv, returning None
# issue for data/batter_data/batting_data_zeilt001.csv, returning None
# issue for data/batter_data/batting_data_zeppb101.csv, returning None
# issue for data/batter_data/batting_data_zerbc001.csv, returning None
# issue for data/batter_data/batting_data_zerng101.csv, returning None
# issue for data/batter_data/batting_data_zimmb001.csv, returning None
# issue for data/batter_data/batting_data_zimmb002.csv, returning None
# issue for data/batter_data/batting_data_zimmd101.csv, returning None
# issue for data/batter_data/batting_data_zimmj003.csv, returning None
# issue for data/batter_data/batting_data_zimmj101.csv, returning None
# issue for data/batter_data/batting_data_zimmr001.csv, returning None
# issue for data/batter_data/batting_data_zinta001.csv, returning None
# 9300
# issue for data/batter_data/batting_data_zipfb101.csv, returning None
# issue for data/batter_data/batting_data_ziskr101.csv, returning None
# issue for data/batter_data/batting_data_zitob001.csv, returning None
# issue for data/batter_data/batting_data_zitzb101.csv, returning None
# issue for data/batter_data/batting_data_zobrb001.csv, returning None
# issue for data/batter_data/batting_data_zoccp001.csv, returning None
# issue for data/batter_data/batting_data_zoske001.csv, returning None
# issue for data/batter_data/batting_data_zubej001.csv, returning None
# issue for data/batter_data/batting_data_zulej001.csv, returning None
# issue for data/batter_data/batting_data_zunim001.csv, returning None
# issue for data/batter_data/batting_data_zupcb001.csv, returning None
# issue for data/batter_data/batting_data_zuvep001.csv, returning None
# issue for data/batter_data/batting_data_zwild101.csv, returning None

# %%
new_col_dict = {}
colstems = ['BATAVG', 'OBP', 'SLG', 'OBS', 'SLGmod','SObat_perc']
winsizes = [30,75,162,350]
new_col_list = [stem+'_'+str(winsize)+'_b'+str(i)+hv   for stem in colstems for winsize in winsizes 
                for i in range(1,10) for hv in ['_h','_v']]
for col in new_col_list:
    new_col_dict[col] = np.empty(df.shape[0])
    new_col_dict[col].fill(np.nan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 new_col_list = [stem+'_'+str(winsize)+'_b'+str(i)+hv   for stem in colstems for winsize in winsizes
#       5                 for i in range(1,10) for hv in ['_h','_v']]
#       6 for col in new_col_list:
# ----> 7     new_col_dict[col] = np.empty(df.shape[0])
#       8     new_col_dict[col].fill(np.nan)
#
# NameError: name 'np' is not defined

# %%
def get_batter_ids_from_row(row):
    b_cols = ['batter1_name_h', 'batter1_name_v', 'batter2_name_h',
       'batter2_name_v', 'batter3_name_h', 'batter3_name_v',
       'batter4_name_h', 'batter4_name_v', 'batter5_name_h',
       'batter5_name_v', 'batter6_name_h', 'batter6_name_v',
       'batter7_name_h', 'batter7_name_v', 'batter8_name_h',
       'batter8_name_v', 'batter9_name_h', 'batter9_name_v']
    return(row.loc[b_cols].to_dict())

# %%
## Add in all the statistics about the starting lineup batters
for i in range(df.shape[0]):
    row = df.iloc[i,:]
    if i%1000==0:
        print(i)
    bid_dict = get_batter_ids_from_row(row)
    date_dblhead = row['date_dblhead']
    for hv in ['_h','_v']:
        for j in range(1,10):
            # Again, check if should be name or id col
            #curr_col = 'batter'+str(j)+'_id'+hv
            curr_col = 'batter'+str(j)+'_name'+hv
            curr_b_id = bid_dict[curr_col]
            if curr_b_id in batter_data_dict.keys():
                curr_batter_df = batter_data_dict[curr_b_id]
                if (curr_batter_df is not None) and (curr_batter_df.shape[0]>0):
                    try:
                        curr_batter_row = curr_batter_df.loc[date_dblhead,:]
                    except:
                        print(f'date not found for batter {curr_b_id} game {date_dblhead}')
                        prev_game_indices = np.where(curr_batter_df.index<date_dblhead)[0]
                        if len(prev_game_indices)==0:
                            index_to_use = 0
                        else:
                            index_to_use = np.max(prev_game_indices)
                        curr_batter_row = curr_batter_df.iloc[index_to_use,:]
                        print(f'using date {curr_batter_df.index[index_to_use]}')
                    if (curr_batter_row.ndim>1):
                        curr_batter_row = curr_batter_row.iloc[0,:]
                    for stem in colstems:
                        for winsize in winsizes:
                            newcolname = stem+'_'+str(winsize)+'_b'+str(j)+hv
                            new_col_dict[newcolname][i] = curr_batter_row[stem+'_'+str(winsize)]
                else:
                    print(f'No data found for {curr_b_id}')
            else:
                print(f'batter not found for {curr_b_id}')
