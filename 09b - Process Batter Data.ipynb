# %% [markdown]
# Add / Process Batter Data
#
#     - Now, we need to process this data and augment our game-level data frame
#     - For each game, we want the trailing statistics for each player designated in the starting lineup
#     - Need to add the statistics for those 18 players to each game
#     - From that, we may want to derive "team-level" averages to simplify our feature set
#     - NOTE: this will complicate things when we "go into production" and try and use this model for predicting new games

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_columns',5000)
pd.set_option('display.max_rows',5000)

# %%
df = pd.read_csv('df_bp7.csv', low_memory=False)
df.shape
# Out:
# (132128, 611)

# %% [markdown]
#     - When aggregating pitcher's past performance, we use default values to "smooth out" players with little / no history
#     - With batters, this is more complicated, as different positions have different "typical" hitting capabilities
#     - (Separate issue: should we be using training data with pitchers hitting?!?!)

# %%
def roll_column(df, col, winsize):
    # do the standard Pandas rolling calc
    t_col = df[col].rolling(winsize, closed='left').sum().to_numpy()
    
    # for the early columns, just do a rolling sum from the beginning
    t_col[:winsize] = np.concatenate(([0],df[col].iloc[:(winsize)].cumsum().to_numpy()[:-1]))

    return(t_col)

# %%
## Set up position level defaults
dd = {}
dd_p = {'batavg': .100, 'obp': .150, 'slg': .180, 'slgmod': .220, 'obs': .330, 'sobat': .3}
dd_ss_c = {'batavg': .205, 'obp': .260, 'slg': .300, 'slgmod': .320, 'obs': .540, 'sobat': .25}
dd_2b_3b = {'batavg': .240, 'obp': .280, 'slg': .350, 'slgmod': .355, 'obs': .630, 'sobat': .2}
dd_rest = {'batavg': .255, 'obp': .310, 'slg': .380, 'slgmod': .430, 'obs': .690, 'sobat': .2}
dd['p'] = dd_p
dd['ss'] = dd_ss_c
dd['c'] = dd_ss_c
dd['2b'] = dd_2b_3b
dd['3b'] = dd_2b_3b
dd['1b'] = dd_rest
dd['lf'] = dd_rest
dd['rf'] = dd_rest
dd['cf'] = dd_rest
dd['ph'] = dd_rest
dd['pr'] = dd_ss_c
dd['dh'] = dd_rest

# %%
def process_batter_df(p_id, dict_def):
    fname = '~/Desktop/beatingVegas/batter_data/batting_data_'+p_id+'.csv'
    try:
        batter_df = pd.read_csv(fname)
        pos = batter_df.Pos.mode()[0]
        
        # corner cases where the most common position was a pair
        if ',' in pos:
            pos = pos.split(',')[0]
            
        batter_df['Date'] = (pd.to_datetime(batter_df.Date).astype(str).str.replace('-','')).astype(int)
        t_col = batter_df['dblhead_num'].copy()
        t_col[np.isnan(t_col)] = 0
        batter_df['dblheader_int'] = t_col.astype(int)
        for winsize in [30,75,162,350]:
            suff = str(winsize)
            for raw_col in ['AB','BB','H','2B','3B','HR','HBP','SO','SB','CS']:
                new_col = 'rollsum_'+raw_col+'_'+suff
                batter_df[new_col] = roll_column(batter_df, raw_col, winsize)

            ab_per_game_def = 2
            pa_per_game_def = 2
            batavg_def = dict_def[pos]['batavg']
            obp_def = dict_def[pos]['obp']
            slg_def = dict_def[pos]['slg']
            slgmod_def = dict_def[pos]['slgmod']
            so_bat_perc_def = dict_def[pos]['sobat']

            # Columns created by aggregation above
            ab_col = 'rollsum_AB_'+str(winsize)
            h_col = 'rollsum_H_'+str(winsize)
            bb_col = 'rollsum_BB_'+str(winsize)
            hbp_col = 'rollsum_HBP_'+str(winsize)
            doub_col = 'rollsum_2B_'+str(winsize)
            trip_col = 'rollsum_3B_'+str(winsize)
            hr_col = 'rollsum_HR_'+str(winsize)
            so_col = 'rollsum_SO_'+str(winsize)

            # Columns I will define below
            abmod_col = 'ABmod_'+str(winsize)
            fakeab_col = 'fakeAB_'+str(winsize)
            pa_col = 'PA_'+str(winsize)
            pamod_col = 'PAmod_'+str(winsize)
            fakepa_col = 'fakePA_'+str(winsize)
            xb_col = 'XB_'+str(winsize) # represents extra bases beyond hits
            slg_col = 'SLG_'+str(winsize)
            slgmod_col = 'SLGmod_'+str(winsize)
            batavg_col = 'BATAVG_'+str(winsize)
            so_bat_perc_col = 'SObat_perc_'+str(winsize)
            obp_col = 'OBP_'+str(winsize)
            obs_col = 'OBS_'+str(winsize)

            # calculate BATAVG, with smoothing for low AB numbers
            batter_df[abmod_col] = np.maximum(batter_df[ab_col],winsize*ab_per_game_def)
            batter_df[fakeab_col] = np.minimum(batter_df[abmod_col]-batter_df[ab_col],0)
            batter_df[batavg_col] = (batter_df[h_col] + (batter_df[fakeab_col]*batavg_def))/(batter_df[abmod_col])

            # calculate SLG, with smoothing for low AB numbers
            batter_df[xb_col] = batter_df[doub_col] + 2*batter_df[trip_col] + 3*batter_df[hr_col]
            batter_df[slg_col] = (batter_df[h_col] + batter_df[xb_col] + 
                                     (batter_df[fakeab_col]*slg_def))/(batter_df[abmod_col])

            # calculate OBP, with smoothing for low PA numbers
            batter_df[pa_col] = batter_df[ab_col]+batter_df[bb_col]+batter_df[hbp_col]
            batter_df[pamod_col] = np.maximum(batter_df[pa_col],winsize*pa_per_game_def)
            batter_df[fakepa_col] = np.minimum(batter_df[pamod_col]-batter_df[pa_col],0)
            batter_df[obp_col] = (batter_df[h_col] + batter_df[bb_col] + batter_df[hbp_col]
                                  + (batter_df[fakepa_col]*obp_def))/(
                                    batter_df[pamod_col])

            # calculate SLGmod, with smoothing for low PA numbers
            batter_df[slgmod_col] = (batter_df[so_col] + batter_df[bb_col] + batter_df[hbp_col] 
                                     +batter_df[xb_col] + (batter_df[fakepa_col]*slgmod_def))/(
                                    batter_df[pamod_col])

            # calculate SObat_perc, with smoothing for low PA numbers
            batter_df[so_bat_perc_col] = (batter_df[so_col] + (batter_df[fakepa_col]*so_bat_perc_def))/(
                                    batter_df[pamod_col])

            # calculate OBS
            batter_df[obs_col] = batter_df[obp_col]+batter_df[slg_col]


            batter_df['date_dblhead'] = (batter_df['Date'].astype(str) + batter_df['dblheader_int'].astype(str)).astype(int)
            batter_df.set_index('date_dblhead', inplace=True)
    except:
        try:
            print(f'issue for {fname} at position {pos}, returning None')
        except:
            print(f'issue for {fname}, returning None')
        batter_df = None
    return(batter_df)

# %%
batter_ids = np.array([])
for num in range(1,10):
    for suffix in ['_h','_v']:
        # Check whether this should be '_id' or '_name'
        colname = 'batter'+str(num)+'_name'+suffix
        batter_ids = np.concatenate((batter_ids, pd.unique(df[colname])))
batter_ids = np.unique(batter_ids)

# %%
## Create a batter data dictionary from the saved batter files
batter_data_dict = {}
for i,b_id in enumerate(batter_ids):
    if i%1000==0:
        print(i)
    batter_data_dict[b_id] = process_batter_df(b_id, dd)
# Out:
# 0
# issue for ~/Desktop/beatingVegas/batter_data/batting_data
101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_sukec101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_sullb103.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_sullj104.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_sullr101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_summh101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_swane101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_sweeb101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_sweel101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_swets101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_swifb102.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_taboj101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_taitd101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_talbb101.csv at position cf, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_tayld101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_taylz101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_tebbb101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_terww101.csv at position 2b, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_thevt101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_thomb001.csv, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_thomf103.csv at position lf, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_thomf106.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_thomt105.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_tinkj101.csv, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_tiptj101.csv at position c, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_tobij101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_todda101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_todtp101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_trayp101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_tresm101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_tuckt102.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_tyacj101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_urbab101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_urbal101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_usheb101.csv at position cf, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_vanrm101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_vauga101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_verbe101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_vergj101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_vernm101.csv at position 1b, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_vitkj001.csv, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_vollc101.csv at position ph, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_vosmj101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wagnh102.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wahlk101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_waldi101.csv, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_walkc101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_walkd101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_walkg101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wallj102.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wanel101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wanep101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_warsr101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wasdj101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_washg101.csv, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_watkg101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wattf101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_watwj101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_webbe101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_welcf101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_welsj101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_welzt101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wests101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_westw101.csv at position c, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wheaz101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_whitb101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_whitg103.csv, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_whitj104.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_whitp103.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_whits103.csv at position c, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wicka101.csv at position Date, returning None
# 9000
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wilbd101.csv at position c, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wilhh101.csv at position p, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_willc103.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_willd104.csv at position 3b, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_willd107.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_willh102.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_willk101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wilsa102.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wilsb103.csv at position cf, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wilsh102.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wilsj105.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wilsr102.csv at position c, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_winge102.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wingt001.csv, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_woodg101.csv at position lf, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_woodp102.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wortr102.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wrigt102.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_wyroj101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_yorkr101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_younb101.csv at position 2b, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_younp101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_yvars101.csv at position c, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_zaria101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_zeidr101.csv, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_zitzb101.csv at position Date, returning None
# issue for ~/Desktop/beatingVegas/batter_data/batting_data_zwild101.csv, returning None

# %%
new_col_dict = {}
colstems = ['BATAVG', 'OBP', 'SLG', 'OBS', 'SLGmod','SObat_perc']
winsizes = [30,75,162,350]
new_col_list = [stem+'_'+str(winsize)+'_b'+str(i)+hv   for stem in colstems for winsize in winsizes 
                for i in range(1,10) for hv in ['_h','_v']]
for col in new_col_list:
    new_col_dict[col] = np.empty(df.shape[0])
    new_col_dict[col].fill(np.nan)

# %%
def get_batter_ids_from_row(row):
    b_cols = ['batter1_name_h', 'batter1_name_v', 'batter2_name_h',
       'batter2_name_v', 'batter3_name_h', 'batter3_name_v',
       'batter4_name_h', 'batter4_name_v', 'batter5_name_h',
       'batter5_name_v', 'batter6_name_h', 'batter6_name_v',
       'batter7_name_h', 'batter7_name_v', 'batter8_name_h',
       'batter8_name_v', 'batter9_name_h', 'batter9_name_v']
    return(row.loc[b_cols].to_dict())

# %%
## Add in all the statistics about the starting lineup batters
for i in range(df.shape[0]):
    row = df.iloc[i,:]
    if i%1000==0:
        print(i)
    bid_dict = get_batter_ids_from_row(row)
    date_dblhead = row['date_dblhead']
    for hv in ['_h','_v']:
        for j in range(1,10):
            # Again, check if should be name or id col
            #curr_col = 'batter'+str(j)+'_id'+hv
            curr_col = 'batter'+str(j)+'_name'+hv
            curr_b_id = bid_dict[curr_col]
            if curr_b_id in batter_data_dict.keys():
                curr_batter_df = batter_data_dict[curr_b_id]
                if (curr_batter_df is not None) and (curr_batter_df.shape[0]>0):
                    try:
                        curr_batter_row = curr_batter_df.loc[date_dblhead,:]
                    except:
                        print(f'date not found for batter {curr_b_id} game {date_dblhead}')
                        prev_game_indices = np.where(curr_batter_df.index<date_dblhead)[0]
                        if len(prev_game_indices)==0:
                            index_to_use = 0
                        else:
                            index_to_use = np.max(prev_game_indices)
                        curr_batter_row = curr_batter_df.iloc[index_to_use,:]
                        print(f'using date {curr_batter_df.index[index_to_use]}')
                    if (curr_batter_row.ndim>1):
                        curr_batter_row = curr_batter_row.iloc[0,:]
                    for stem in colstems:
                        for winsize in winsizes:
                            newcolname = stem+'_'+str(winsize)+'_b'+str(j)+hv
                            new_col_dict[newcolname][i] = curr_batter_row[stem+'_'+str(winsize)]
                else:
                    print(f'No data found for {curr_b_id}')
            else:
                print(f'batter not found for {curr_b_id}')
# Out:
# 0
# No data found for waldi101
# No data found for gilbb103
# No data found for hallb102
# No data found for andej101
# No data found for conrw101
# No data found for duffh101
# No data found for burkj104
# No data found for leaht101
# No data found for hawlp101
# No data found for farrj103
# No data found for dungs101
# No data found for quinj103
# No data found for fostp101
# No data found for everb101
# No data found for gradm101
# No data found for clinb101
# No data found for cougb101
# No data found for carrb102
# No data found for farrj103
# No data found for clarb103
# No data found for dungs101
# No data found for fostp101
# No data found for geard102
# No data found for lee-w101
# No data found for cougb101
# No data found for clinb101
# No data found for carrb102
# No data found for waldi101
# No data found for frieb103
# No data found for hallb102
# No data found for andej101
# No data found for conrw101
# No data found for duffh101
# No data found for burkj104
# No data found for malob101
# No data found for hawlp101
# No data found for tobij101
# No data found for bouca101
# No data found for millw104
# No data found for kommf101
# No data found for hartg102
# No data found for missj101
# No data found for brida101
# No data found for simom102
# No data found for keuph101
# No data found for campv101
# No data found for mckeb101
# No data found for kaufb101
# No data found for lapof101
# No data found for schea102
# No data found for esmoj101
# No data found for rouse101
# No data found for rarib101
# No data found for kaisg101
# No data found for zeidr101
# No data found for tinkj101
# No data found for wilsa102
# No data found for zwild101
# No data found for wicka101
# No data found for beckf101
# No data found for flacm101
# No data found for farrj104
# No data found for lange101
# No data found for tobij101
# No data found for millw104
# No data found for drakd101
# No data found for millh102
# No data found for bouca101
# No data found for brida101
# No data found for missj101
# No data found for chaph102
# No data found for keuph101
# No data found for campv101
# No data found for esmoj101
# No data found for rouse101
# No data found for lapof101
# No data found for schea102
# No data found for mckeb101
# No data found for millr114
# No data found for rarib101
# No data found for kaisg101
# No data found for chadc101
# No data found for rawlj101
# No data found for stovg101
# No data found for perrg102
# No data found for shawa102
# No data found for bradb102
# No data found for gilmg101
# No data found for eastt101
# No data found for hennp101
# No data found for chadc101
# No data found for kruga101
# No data found for shawa102
# No data found for eastt101
# No data found for kenwd101
# No data found for perrg102
# No data found for bradb102
# No data found for rawlj101
# No data found for hennp101
# No data found for whitg103
# No data found for reedt101
# No data found for rouse101
# No data found for lapof101
# No data found for esmoj101
# No data found for schea102
# No data found for millr114
# No data found for huhne101
# No data found for kaisg101
# No data found for mitcj101
# No data found for menom101
# No data found for burng102
# No data found for pratd101
# No data found for harrj103
# No data found for colls101
# No data found for pittp101
# No data found for chape102
# No data found for karrb101
# No data found for tobij101
# No data found for foste103
# No data found for sislg101
# No data found for willk101
# No data found for jacow101
# No data found for mcmam101
# No data found for seveh101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# date not found for batter ryann001 game 196609181
# using date 196804140
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# 11000
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# date not found for batter monta103 game 196707162
# using date 196607200
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# 12000
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# 13000
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# date not found for batter santa101 game 196809100
# using date 196904130
# 14000
# date not found for batter bails102 game 196809140
# using date 196709300
# No data found for schod101
# No data found for schod101
# No data found for schod101
# date not found for batter rossg102 game 196904222
# using date 196809200
# No data found for schod101
# date not found for batter branb102 game 196905042
# using date 196809240
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for hillg101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# date not found for batter morrd102 game 196906170
# using date 196809240
# No data found for schod101
# No data found for schod101
# No data found for washg101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for washg101
# No data found for schod101
# No data found for schod101
# 15000
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# date not found for batter pascc102 game 196908030
# using date 196907042
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# date not found for batter reynb102 game 196909191
# using date 197106180
# 16000
# No data found for schod101
# No data found for schod101
# date not found for batter mcqum103 game 196910020
# using date 197006060
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for peter103
# No data found for peter103
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# 17000
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# date not found for batter millb106 game 197009182
# using date 197008301
# 18000
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# 19000
# No data found for schod101
# No data found for schod101
# No data found for schod101
# No data found for schod101
# 20000
# 21000
# date not found for batter richj101 game 197207301
# using date 197109220
# date not found for batter medid101 game 197209050
# using date 197404080
# date not found for batter garmm101 game 197209210
# using date 197109290
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# date not found for batter langc101 game 197509081
# using date 197605230
# 28000
# 29000
# No data found for minom101
# No data found for minom101
# No data found for minom101
# 30000
# 31000
# 32000
# 33000
# date not found for batter seoam101 game 197809032
# using date 197709280
# date not found for batter jameb001 game 197809070
# using date 198307120
# 34000
# 35000
# date not found for batter capid101 game 197909191
# using date 197904280
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# date not found for batter schud001 game 198405260
# using date 198310010
# 45000
# 46000
# No data found for oconj001
# 47000
# 48000
# 49000
# date not found for batter smitm001 game 198609200
# using date 198404220
# date not found for batter penah001 game 198610050
# using date 198704290
# 50000
# 51000
# date not found for batter lea-c001 game 198709160
# using date 198409160
# date not found for batter mallr001 game 198710020
# using date 199108170
# 52000
# 53000
# date not found for batter krueb001 game 198807040
# using date 199209050
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# No data found for vitkj001
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# date not found for batter barbb002 game 199604140
# using date 199510010
# 69000
# No data found for quirr001
# 70000
# date not found for batter cormr001 game 199704050
# using date 199609270
# 71000
# 72000
# No data found for karpr001
# date not found for batter myerr002 game 199709270
# using date 199609272
# 73000
# 74000
# 75000
# date not found for batter ojalk001 game 199904180
# using date 199809272
# 76000
# date not found for batter fyhrm001 game 199907110
# using date 200104020
# 77000
# date not found for batter tejem001 game 199909080
# using date 200204030
# 78000
# date not found for batter rigdp001 game 200006070
# using date 200007290
# 79000
# date not found for batter beltr001 game 200007171
# using date 199910020
# 80000
# 81000
# No data found for thomb001
# date not found for batter loewc001 game 200106160
# using date 199909290
# date not found for batter boroj001 game 200108110
# using date 199609290
# 82000
# 83000
# 84000
# 85000
# date not found for batter tankd001 game 200304090
# using date 200209280
# date not found for batter daalo001 game 200306050
# using date 200209270
# date not found for batter biern001 game 200306060
# using date 200107230
# 86000
# No data found for rosar001
# 87000
# date not found for batter fernj002 game 200404120
# using date 200309260
# 88000
# date not found for batter reyns001 game 200406280
# using date 200309270
# date not found for batter tejem001 game 200407010
# using date 200309280
# 89000
# 90000
# 91000
# 92000
# date not found for batter rasnd001 game 200509060
# using date 200805040
# 93000
# 94000
# 95000
# date not found for batter rasnd001 game 200705190
# using date 200805040
# 96000
# 97000
# 98000
# date not found for batter albem001 game 200806250
# using date 200709280
# date not found for batter muldm001 game 200807090
# using date 200709160
# 99000
# date not found for batter guzma001 game 200809280
# using date 200706010
# 100000
# 101000
# date not found for batter chacj001 game 200908110
# using date 201004270
# 102000
# date not found for batter jakuc001 game 201004240
# using date 200909250
# date not found for batter eveld001 game 201005220
# using date 200809240
# 103000
# 104000
# 105000
# 106000
# 107000
# date not found for batter marqj001 game 201205200
# using date 201108140
# 108000
# date not found for batter valdr002 game 201206270
# using date 201010020
# 109000
# 110000
# 111000
# 112000
# date not found for batter hendl001 game 201406200
# using date 201209300
# 113000
# 114000
# No data found for gelts001
# 115000
# No data found for gelts001
# date not found for batter garcy001 game 201507060
# using date 201409280
# date not found for batter gravk001 game 201507260
# using date 201604070
# 116000
# date not found for batter gonzm005 game 201509010
# using date 201409280
# No data found for garcf003
# 117000
# 118000
# date not found for batter mayem001 game 201607240
# using date 201803290
# date not found for batter matub001 game 201607310
# using date 201210020
# date not found for batter gilms001 game 201609240
# using date 201510010
# 119000
# date not found for batter guthj001 game 201704080
# using date 201509260
# date not found for batter skoge001 game 201706090
# using date 201804100
# 120000
# 121000
# 122000
# date not found for batter tsenj001 game 201805080
# using date 201709280
# date not found for batter fulmc001 game 201805110
# using date 201904080
# date not found for batter ventj001 game 201806060
# using date 201010030
# date not found for batter andrm001 game 201807040
# using date 201609300
# No data found for stanr002
# date not found for batter flexc001 game 201807080
# using date 201710010
# 123000
# No data found for stanr002
# date not found for batter garcj004 game 201809081
# using date 201808200
# No data found for sadzc001
# No data found for claua001
# 124000
# No data found for stanr002
# date not found for batter barnj002 game 201905010
# using date 201709300
# No data found for stanr002
# date not found for batter felim001 game 201905240
# using date 201809300
# date not found for batter alvaj003 game 201906010
# using date 201610010
# No data found for bedrc001
# 125000
# No data found for ramin002
# No data found for colet001
# No data found for colet001
# No data found for boshb001
# date not found for batter fontw001 game 201908210
# using date 201907070
# No data found for wingt001
# 126000
# date not found for batter fontw001 game 201909030
# using date 201907070
# date not found for batter gausk001 game 201909160
# using date 201908020
# date not found for batter snelb001 game 201909170
# using date 201809290
# date not found for batter walkt004 game 201909290
# using date 201804140
# No data found for baezm001
# 127000
# No data found for castm002
# No data found for castm002
# date not found for batter haled001 game 202105200
# using date 201510010
# 128000
# date not found for batter menec001 game 202106122
# using date 201909270
# No data found for gonzv001
# date not found for batter reedj005 game 202107070
# using date 202108150
# date not found for batter bassa001 game 202107090
# using date 201309190
# date not found for batter loupa001 game 202107110
# using date 201210020
# No data found for nuned002
# No data found for middk001
# date not found for batter loupa001 game 202107262
# using date 201210020
# No data found for oviel001
# No data found for sancc002
# No data found for brogc001
# 129000
# date not found for batter stram001 game 202108170
# using date 201909290
# date not found for batter johnp001 game 202108240
# using date 201809300
# date not found for batter leond003 game 202109050
# using date 201809280
# date not found for batter howas003 game 202109070
# using date 202107260
# date not found for batter mayem001 game 202109080
# using date 201909270
# date not found for batter leond003 game 202109100
# using date 201809280
# date not found for batter leond003 game 202109130
# using date 201809280
# date not found for batter leond003 game 202109150
# using date 201809280
# No data found for bedrc001
# date not found for batter johnp001 game 202109160
# using date 201809300
# No data found for greec004
# date not found for batter howas002 game 202109240
# using date 201909290
# date not found for batter syndn001 game 202109282
# using date 201909290
# No data found for contr001
# date not found for batter syndn001 game 202110030
# using date 201909290
# 130000
# 131000
# 132000

# %%
for key, val in new_col_dict.items():
    df[key] = val
# Out:
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# ...
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val

# %%
df = df.copy()

# %%
newcols = new_col_dict.keys()

# %% [markdown]
# Deal with missing data

# %%
df.loc[:,newcols].isnull().sum()
# Out:
# BATAVG_30_b1_h          721
# BATAVG_30_b1_v          764
# BATAVG_30_b2_h         1053
# BATAVG_30_b2_v         1090
# BATAVG_30_b3_h          482
# BATAVG_30_b3_v          520
# BATAVG_30_b4_h          724
# BATAVG_30_b4_v          717
# BATAVG_30_b5_h          815
# BATAVG_30_b5_v          756
# BATAVG_30_b6_h          662
# BATAVG_30_b6_v          682
# BATAVG_30_b7_h          767
# BATAVG_30_b7_v          733
# BATAVG_30_b8_h         1140
# BATAVG_30_b8_v         1068
# BATAVG_30_b9_h          728
# BATAVG_30_b9_v          740
# BATAVG_75_b1_h          721
# BATAVG_75_b1_v          764
# BATAVG_75_b2_h         1053
# BATAVG_75_b2_v         1090
# BATAVG_75_b3_h          482
# BATAVG_75_b3_v          520
# BATAVG_75_b4_h          724
# BATAVG_75_b4_v          717
# BATAVG_75_b5_h          815
# BATAVG_75_b5_v          756
# BATAVG_75_b6_h          662
# BATAVG_75_b6_v          682
# BATAVG_75_b7_h          767
# BATAVG_75_b7_v          733
# BATAVG_75_b8_h         1140
# BATAVG_75_b8_v         1068
# BATAVG_75_b9_h          728
# BATAVG_75_b9_v          740
# BATAVG_162_b1_h         721
# BATAVG_162_b1_v         764
# BATAVG_162_b2_h        1053
# BATAVG_162_b2_v        1090
# BATAVG_162_b3_h         482
# BATAVG_162_b3_v         520
# BATAVG_162_b4_h         724
# BATAVG_162_b4_v         717
# BATAVG_162_b5_h         815
# BATAVG_162_b5_v         756
# BATAVG_162_b6_h         662
# BATAVG_162_b6_v         682
# BATAVG_162_b7_h         767
# BATAVG_162_b7_v         733
# BATAVG_162_b8_h        1140
# BATAVG_162_b8_v        1068
# BATAVG_162_b9_h         728
# BATAVG_162_b9_v         740
# BATAVG_350_b1_h         721
# BATAVG_350_b1_v         764
# BATAVG_350_b2_h        1053
# BATAVG_350_b2_v        1090
# BATAVG_350_b3_h         482
# BATAVG_350_b3_v         520
# BATAVG_350_b4_h         724
# BATAVG_350_b4_v         717
# BATAVG_350_b5_h         815
# BATAVG_350_b5_v         756
# BATAVG_350_b6_h         662
# BATAVG_350_b6_v         682
# BATAVG_350_b7_h         767
# BATAVG_350_b7_v         733
# BATAVG_350_b8_h        1140
# BATAVG_350_b8_v        1068
# BATAVG_350_b9_h         728
# BATAVG_350_b9_v         740
# OBP_30_b1_h             721
# OBP_30_b1_v             764
# OBP_30_b2_h            1053
# OBP_30_b2_v            1090
# OBP_30_b3_h             482
# OBP_30_b3_v             520
# OBP_30_b4_h             724
# OBP_30_b4_v             717
# OBP_30_b5_h             815
# OBP_30_b5_v             756
# OBP_30_b6_h             662
# OBP_30_b6_v             682
# OBP_30_b7_h             767
# OBP_30_b7_v             733
# OBP_30_b8_h            1140
# OBP_30_b8_v            1068
# OBP_30_b9_h             728
# OBP_30_b9_v             740
# OBP_75_b1_h             721
# OBP_75_b1_v             764
# OBP_75_b2_h            1053
# OBP_75_b2_v            1090
# OBP_75_b3_h             482
# OBP_75_b3_v             520
# OBP_75_b4_h             724
# OBP_75_b4_v             717
# OBP_75_b5_h             815
# OBP_75_b5_v             756
# OBP_75_b6_h             662
# OBP_75_b6_v             682
# OBP_75_b7_h             767
# OBP_75_b7_v             733
# OBP_75_b8_h            1140
# OBP_75_b8_v            1068
# OBP_75_b9_h             728
# OBP_75_b9_v             740
# OBP_162_b1_h            721
# OBP_162_b1_v            764
# OBP_162_b2_h           1053
# OBP_162_b2_v           1090
# OBP_162_b3_h            482
# OBP_162_b3_v            520
# OBP_162_b4_h            724
# OBP_162_b4_v            717
# OBP_162_b5_h            815
# OBP_162_b5_v            756
# OBP_162_b6_h            662
# OBP_162_b6_v            682
# OBP_162_b7_h            767
# OBP_162_b7_v            733
# OBP_162_b8_h           1140
# OBP_162_b8_v           1068
# OBP_162_b9_h            728
# OBP_162_b9_v            740
# OBP_350_b1_h            721
# OBP_350_b1_v            764
# OBP_350_b2_h           1053
# OBP_350_b2_v           1090
# OBP_350_b3_h            482
# OBP_350_b3_v            520
# OBP_350_b4_h            724
# OBP_350_b4_v            717
# OBP_350_b5_h            815
# OBP_350_b5_v            756
# OBP_350_b6_h            662
# OBP_350_b6_v            682
# OBP_350_b7_h            767
# OBP_350_b7_v            733
# OBP_350_b8_h           1140
# OBP_350_b8_v           1068
# OBP_350_b9_h            728
# OBP_350_b9_v            740
# SLG_30_b1_h             721
# SLG_30_b1_v             764
# SLG_30_b2_h            1053
# SLG_30_b2_v            1090
# SLG_30_b3_h             482
# SLG_30_b3_v             520
# SLG_30_b4_h             724
# SLG_30_b4_v             717
# SLG_30_b5_h             815
# SLG_30_b5_v             756
# SLG_30_b6_h             662
# SLG_30_b6_v             682
# SLG_30_b7_h             767
# SLG_30_b7_v             733
# SLG_30_b8_h            1140
# SLG_30_b8_v            1068
# SLG_30_b9_h             728
# SLG_30_b9_v             740
# SLG_75_b1_h             721
# SLG_75_b1_v             764
# SLG_75_b2_h            1053
# SLG_75_b2_v            1090
# SLG_75_b3_h             482
# SLG_75_b3_v             520
# SLG_75_b4_h             724
# SLG_75_b4_v             717
# SLG_75_b5_h             815
# SLG_75_b5_v             756
# SLG_75_b6_h             662
# SLG_75_b6_v             682
# SLG_75_b7_h             767
# SLG_75_b7_v             733
# SLG_75_b8_h            1140
# SLG_75_b8_v            1068
# SLG_75_b9_h             728
# SLG_75_b9_v             740
# SLG_162_b1_h            721
# SLG_162_b1_v            764
# SLG_162_b2_h           1053
# SLG_162_b2_v           1090
# SLG_162_b3_h            482
# SLG_162_b3_v            520
# SLG_162_b4_h            724
# SLG_162_b4_v            717
# SLG_162_b5_h            815
# SLG_162_b5_v            756
# SLG_162_b6_h            662
# SLG_162_b6_v            682
# SLG_162_b7_h            767
# SLG_162_b7_v            733
# SLG_162_b8_h           1140
# SLG_162_b8_v           1068
# SLG_162_b9_h            728
# SLG_162_b9_v            740
# SLG_350_b1_h            721
# SLG_350_b1_v            764
# SLG_350_b2_h           1053
# SLG_350_b2_v           1090
# SLG_350_b3_h            482
# SLG_350_b3_v            520
# SLG_350_b4_h            724
# SLG_350_b4_v            717
# SLG_350_b5_h            815
# SLG_350_b5_v            756
# SLG_350_b6_h            662
# SLG_350_b6_v            682
# SLG_350_b7_h            767
# SLG_350_b7_v            733
# SLG_350_b8_h           1140
# SLG_350_b8_v           1068
# SLG_350_b9_h            728
# SLG_350_b9_v            740
# OBS_30_b1_h             721
# OBS_30_b1_v             764
# OBS_30_b2_h            1053
# OBS_30_b2_v            1090
# OBS_30_b3_h             482
# OBS_30_b3_v             520
# OBS_30_b4_h             724
# OBS_30_b4_v             717
# OBS_30_b5_h             815
# OBS_30_b5_v             756
# OBS_30_b6_h             662
# OBS_30_b6_v             682
# OBS_30_b7_h             767
# OBS_30_b7_v             733
# OBS_30_b8_h            1140
# OBS_30_b8_v            1068
# OBS_30_b9_h             728
# OBS_30_b9_v             740
# OBS_75_b1_h             721
# OBS_75_b1_v             764
# OBS_75_b2_h            1053
# OBS_75_b2_v            1090
# OBS_75_b3_h             482
# OBS_75_b3_v             520
# OBS_75_b4_h             724
# OBS_75_b4_v             717
# OBS_75_b5_h             815
# OBS_75_b5_v             756
# OBS_75_b6_h             662
# OBS_75_b6_v             682
# OBS_75_b7_h             767
# OBS_75_b7_v             733
# OBS_75_b8_h            1140
# OBS_75_b8_v            1068
# OBS_75_b9_h             728
# OBS_75_b9_v             740
# OBS_162_b1_h            721
# OBS_162_b1_v            764
# OBS_162_b2_h           1053
# OBS_162_b2_v           1090
# OBS_162_b3_h            482
# OBS_162_b3_v            520
# OBS_162_b4_h            724
# OBS_162_b4_v            717
# OBS_162_b5_h            815
# OBS_162_b5_v            756
# OBS_162_b6_h            662
# OBS_162_b6_v            682
# OBS_162_b7_h            767
# OBS_162_b7_v            733
# OBS_162_b8_h           1140
# OBS_162_b8_v           1068
# OBS_162_b9_h            728
# OBS_162_b9_v            740
# OBS_350_b1_h            721
# OBS_350_b1_v            764
# OBS_350_b2_h           1053
# OBS_350_b2_v           1090
# OBS_350_b3_h            482
# OBS_350_b3_v            520
# OBS_350_b4_h            724
# OBS_350_b4_v            717
# OBS_350_b5_h            815
# OBS_350_b5_v            756
# OBS_350_b6_h            662
# OBS_350_b6_v            682
# OBS_350_b7_h            767
# OBS_350_b7_v            733
# OBS_350_b8_h           1140
# OBS_350_b8_v           1068
# OBS_350_b9_h            728
# SObat_perc_75_b2_v     1090
# SObat_perc_75_b3_h      482
# SObat_perc_75_b3_v      520
# SObat_perc_75_b4_h      724
# SObat_perc_75_b4_v      717
# SObat_perc_75_b5_h      815
# SObat_perc_75_b5_v      756
# SObat_perc_75_b6_h      662
# SObat_perc_75_b6_v      682
# SObat_perc_75_b7_h      767
# SObat_perc_75_b7_v      733
# SObat_perc_75_b8_h     1140
# SObat_perc_75_b8_v     1068
# SObat_perc_75_b9_h      728
# SObat_perc_75_b9_v      740
# SObat_perc_162_b1_h     721
# SObat_perc_162_b1_v     764
# SObat_perc_162_b2_h    1053
# SObat_perc_162_b2_v    1090
# SObat_perc_162_b3_h     482
# SObat_perc_162_b3_v     520
# SObat_perc_162_b4_h     724
# SObat_perc_162_b4_v     717
# SObat_perc_162_b5_h     815
# SObat_perc_162_b5_v     756
# SObat_perc_162_b6_h     662
# SObat_perc_162_b6_v     682
# SObat_perc_162_b7_h     767
# SObat_perc_162_b7_v     733
# SObat_perc_162_b8_h    1140
# SObat_perc_162_b8_v    1068
# SObat_perc_162_b9_h     728
# SObat_perc_162_b9_v     740
# SObat_perc_350_b1_h     721
# SObat_perc_350_b1_v     764
# SObat_perc_350_b2_h    1053
# SObat_perc_350_b2_v    1090
# SObat_perc_350_b3_h     482
# SObat_perc_350_b3_v     520
# SObat_perc_350_b4_h     724
# SObat_perc_350_b4_v     717
# SObat_perc_350_b5_h     815
# SObat_perc_350_b5_v     756
# SObat_perc_350_b6_h     662
# SObat_perc_350_b6_v     682
# SObat_perc_350_b7_h     767
# SObat_perc_350_b7_v     733
# SObat_perc_350_b8_h    1140
# SObat_perc_350_b8_v    1068
# SObat_perc_350_b9_h     728
# SObat_perc_350_b9_v     740
# dtype: int64

# %%
newcols89 = [stem+'_'+str(winsize)+'_b'+str(i)+hv   for stem in colstems for winsize in winsizes 
                 for hv in ['_h','_v'] for i in range(8,10)]
for col in newcols89:
    stem=col.split('_')[0].lower()
    df[col].fillna(dd['p'][stem])

# %% [markdown]
# Create some summary features

# %%
w9 = np.array([0.12541131, 0.12159052, 0.11787189, 0.11434144, 0.11096691,
       0.10772781, 0.10430724, 0.10078822, 0.09699465])
w8 = w9[:-1]/np.sum(w9[:-1])

# %%
for col in ['BATAVG', 'OBP', 'SLG', 'OBS', 'SLGmod','SObat_perc']:
    for winsize in winsizes:
        for hv in ['_h','_v']:
            b_cols9 = [col+'_'+str(winsize)+'_b'+str(i)+hv for i in range(1,10)]
            b_cols8 = [col+'_'+str(winsize)+'_b'+str(i)+hv for i in range(1,9)]
            fcolname9 = 'lineup9_'+col+'_'+str(winsize)+hv
            fcolname8 = 'lineup8_'+col+'_'+str(winsize)+hv
            fcolname9w = 'lineup9_'+col+'_'+str(winsize)+'_w'+hv
            fcolname8w = 'lineup8_'+col+'_'+str(winsize)+'_w'+hv
            df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
            df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
            df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
            df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# Out:
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /var/folders/w8/vvmn7s9x2yzffnkyk6j2j_xc0000gn/T/ipykernel_9794/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)

# %%
df.to_csv('df_bp9.csv', index=False)
